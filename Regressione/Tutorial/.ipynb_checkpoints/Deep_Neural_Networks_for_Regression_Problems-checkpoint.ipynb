# %% [markdown]
# # Deep Neural Networks for Regression problems

# %% [markdown]
# ## Contents :
#     1- Process the dataset
#     2- Make the deep neural network
#     3- Train the DNN
#     4- Test the DNN
#     5- Compare the result from the DNN to another ML algorithm

# %% [markdown]
# **First of all, we will import the needed dependencies :**

# %%
from keras.callbacks import ModelCheckpoint
from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error 
from matplotlib import pyplot as plt
import seaborn as sb
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')
warnings.filterwarnings('ignore', category=DeprecationWarning)
from xgboost import XGBRegressor
import h5py

# %% [markdown]
# ## First : Processing the dataset
# We will not go deep in processing the dataset, all we want to do is getting the dataset ready to be fed into our models .
#
# We will get rid of any features with missing values, then we will encode the categorical features, that's it.

# %% [markdown]
# ### Load the dataset :
# * Load train and test data into pandas DataFrames
# * Combine train and test data to process them together

# %%
def get_data():
    #get train data
    train_data_path ='train.csv'
    train = pd.read_csv(train_data_path)
    
    #get test data
    test_data_path ='test.csv'
    test = pd.read_csv(test_data_path)
    
    return train , test

def get_combined_data():
  #reading train data
  train , test = get_data()

  target = train.SalePrice
  train.drop(['SalePrice'],axis = 1 , inplace = True)

  combined = train.append(test)
  combined.reset_index(inplace=True)
  combined.drop(['index', 'Id'], inplace=True, axis=1)
  return combined, target

#Load train and test data into pandas DataFrames
train_data, test_data = get_data()

#Combine train and test data to process them together
combined, target = get_combined_data()

# %%
combined.describe()
# Out:
#         MSSubClass  LotFrontage        LotArea  OverallQual  OverallCond  \
# count  2919.000000  2433.000000    2919.000000  2919.000000  2919.000000
# mean     57.137718    69.305795   10168.114080     6.089072     5.564577
# std      42.517628    23.344905    7886.996359     1.409947     1.113131
# min      20.000000    21.000000    1300.000000     1.000000     1.000000
# 25%      20.000000    59.000000    7478.000000     5.000000     5.000000
# 50%      50.000000    68.000000    9453.000000     6.000000     5.000000
# 75%      70.000000    80.000000   11570.000000     7.000000     6.000000
# max     190.000000   313.000000  215245.000000    10.000000     9.000000
#
#          YearBuilt  YearRemodAdd   MasVnrArea   BsmtFinSF1   BsmtFinSF2  ...  \
# count  2919.000000   2919.000000  2896.000000  2918.000000  2918.000000  ...
# mean   1971.312778   1984.264474   102.201312   441.423235    49.582248  ...
# std      30.291442     20.894344   179.334253   455.610826   169.205611  ...
# min    1872.000000   1950.000000     0.000000     0.000000     0.000000  ...
# 25%    1953.500000   1965.000000     0.000000     0.000000     0.000000  ...
# 50%    1973.000000   1993.000000     0.000000   368.500000     0.000000  ...
# 75%    2001.000000   2004.000000   164.000000   733.000000     0.000000  ...
# max    2010.000000   2010.000000  1600.000000  5644.000000  1526.000000  ...
#
#         GarageArea   WoodDeckSF  OpenPorchSF  EnclosedPorch    3SsnPorch  \
# count  2918.000000  2919.000000  2919.000000    2919.000000  2919.000000
# mean    472.874572    93.709832    47.486811      23.098321     2.602261
# std     215.394815   126.526589    67.575493      64.244246    25.188169
# min       0.000000     0.000000     0.000000       0.000000     0.000000
# 25%     320.000000     0.000000     0.000000       0.000000     0.000000
# 50%     480.000000     0.000000    26.000000       0.000000     0.000000
# 75%     576.000000   168.000000    70.000000       0.000000     0.000000
# max    1488.000000  1424.000000   742.000000    1012.000000   508.000000
#
#        ScreenPorch     PoolArea       MiscVal       MoSold       YrSold
# count  2919.000000  2919.000000   2919.000000  2919.000000  2919.000000
# mean     16.062350     2.251799     50.825968     6.213087  2007.792737
# std      56.184365    35.663946    567.402211     2.714762     1.314964
# min       0.000000     0.000000      0.000000     1.000000  2006.000000
# 25%       0.000000     0.000000      0.000000     4.000000  2007.000000
# 50%       0.000000     0.000000      0.000000     6.000000  2008.000000
# 75%       0.000000     0.000000      0.000000     8.000000  2009.000000
# max     576.000000   800.000000  17000.000000    12.000000  2010.000000
#
# [8 rows x 36 columns]

# %% [markdown]
# let's define a function to get the columns that don't have any missing values

# %%
def get_cols_with_no_nans(df,col_type):
    '''
    Arguments :
    df : The dataframe to process
    col_type : 
          num : to only get numerical columns with no nans
          no_num : to only get nun-numerical columns with no nans
          all : to get any columns with no nans    
    '''
    if (col_type == 'num'):
        predictors = df.select_dtypes(exclude=['object'])
    elif (col_type == 'no_num'):
        predictors = df.select_dtypes(include=['object'])
    elif (col_type == 'all'):
        predictors = df
    else :
        print('Error : choose a type (num, no_num, all)')
        return 0
    cols_with_no_nans = []
    for col in predictors.columns:
        if not df[col].isnull().any():
            cols_with_no_nans.append(col)
    return cols_with_no_nans

# %% [markdown]
# Get the columns that do not have any missing values .

# %%
num_cols = get_cols_with_no_nans(combined , 'num')
cat_cols = get_cols_with_no_nans(combined , 'no_num')

# %% [markdown]
# Let's see how many columns we got

# %%
print ('Number of numerical columns with no nan values :',len(num_cols))
print ('Number of nun-numerical columns with no nan values :',len(cat_cols))
# Out:
# Number of numerical columns with no nan values : 25
# Number of nun-numerical columns with no nan values : 20

# %%
combined = combined[num_cols + cat_cols]
combined.hist(figsize = (12,10))
plt.show()

# %% [markdown]
# **The correlation between the features**

# %%
train_data = train_data[num_cols + cat_cols]
train_data['Target'] = target

C_mat = train_data.corr()
fig = plt.figure(figsize = (15,15))

sb.heatmap(C_mat, vmax = .8, square = True)
plt.show()

# %% [markdown]
# From the correlation heatmap above, we see that about 15 features are highly correlated with the target.

# %% [markdown]
# **One Hot Encode The Categorical Features :**
#
# We will encode the categorical features using one hot encoding.

# %%
def oneHotEncode(df,colNames):
    for col in colNames:
        if( df[col].dtype == np.dtype('object')):
            dummies = pd.get_dummies(df[col],prefix=col)
            df = pd.concat([df,dummies],axis=1)

            #drop the encoded column
            df.drop([col],axis = 1 , inplace=True)
    return df

# %%
print('There were {} columns before encoding categorical features'.format(combined.shape[1]))
combined = oneHotEncode(combined, cat_cols)
print('There are {} columns after encoding categorical features'.format(combined.shape[1]))
# Out:
# There were 45 columns before encoding categorical features
# There are 149 columns after encoding categorical features

# %% [markdown]
# Now, split back combined dataFrame to training data and test data

# %%
def split_combined():
    global combined
    train = combined[:1460]
    test = combined[1460:]

    return train , test

# %%
train, test = split_combined()

# %% [markdown]
# ## Second : Make the Deep Neural Network
#  * Define a sequential model
#  * Add some dense layers
#  * Use '**relu**' as the activation function in the hidden layers
#  * Use a '**normal**' initializer as the kernal_intializer
#            Initializers define the way to set the initial random weights of Keras layers.
#  * We will use mean_absolute_error as a loss function
#  * Define the output layer with only one node
#  * Use 'linear 'as the activation function for the output layer

# %%
NN_model = Sequential()

# %% [markdown]
# **The Input Layer**

# %%
NN_model.add(Dense(128, kernel_initializer='normal',input_dim = train.shape[1], activation='relu'))
# Out:
# WARNING:tensorflow:From /home/paologio/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# **The Hidden Layers**

# %%
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))
NN_model.add(Dense(256, kernel_initializer='normal',activation='relu'))

# %% [markdown]
# **The Output Layer**

# %%
NN_model.add(Dense(1, kernel_initializer='normal',activation='linear'))

# %% [markdown]
# **Compile the network**

# %%
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])
NN_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 128)               19200
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               33024
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_4 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 257
# =================================================================
# Total params: 184,065
# Trainable params: 184,065
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Define a checkpoint callback :**

# %%
checkpoint_name = 'Weights-{epoch:03d}--{val_loss:.5f}.hdf5' 
checkpoint = ModelCheckpoint(checkpoint_name, monitor='val_loss', verbose = 1, save_best_only = True, mode ='auto')
callbacks_list = [checkpoint]

# %% [markdown]
# ## Third : Train the model :

# %%
NN_model.fit(train, target, epochs=500, batch_size=32, validation_split = 0.2, callbacks=callbacks_list)
# Out:
# WARNING:tensorflow:From /home/paologio/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1168 samples, validate on 292 samples
# Epoch 1/500
# 1168/1168 [==============================] - 0s 414us/step - loss: 135245.4810 - mean_absolute_error: 135245.4810 - val_loss: 61088.6468 - val_mean_absolute_error: 61088.6468
#
# Epoch 00001: val_loss improved from inf to 61088.64683, saving model to Weights-001--61088.64683.hdf5
# Epoch 2/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 53999.7373 - mean_absolute_error: 53999.7373 - val_loss: 47747.6704 - val_mean_absolute_error: 47747.6704
#
# Epoch 00002: val_loss improved from 61088.64683 to 47747.67038, saving model to Weights-002--47747.67038.hdf5
# Epoch 3/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 45717.0360 - mean_absolute_error: 45717.0360 - val_loss: 44214.8237 - val_mean_absolute_error: 44214.8237
#
# Epoch 00003: val_loss improved from 47747.67038 to 44214.82374, saving model to Weights-003--44214.82374.hdf5
# Epoch 4/500
# 1168/1168 [==============================] - 0s 116us/step - loss: 41394.8518 - mean_absolute_error: 41394.8518 - val_loss: 41482.5452 - val_mean_absolute_error: 41482.5452
#
# Epoch 00004: val_loss improved from 44214.82374 to 41482.54522, saving model to Weights-004--41482.54522.hdf5
# Epoch 5/500
# 1168/1168 [==============================] - 0s 123us/step - loss: 39576.3334 - mean_absolute_error: 39576.3334 - val_loss: 42771.9149 - val_mean_absolute_error: 42771.9149
#
# Epoch 00005: val_loss did not improve from 41482.54522
# Epoch 6/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 36948.5310 - mean_absolute_error: 36948.5310 - val_loss: 38698.3536 - val_mean_absolute_error: 38698.3536
#
# Epoch 00006: val_loss improved from 41482.54522 to 38698.35365, saving model to Weights-006--38698.35365.hdf5
# Epoch 7/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 35311.5592 - mean_absolute_error: 35311.5592 - val_loss: 37677.6722 - val_mean_absolute_error: 37677.6722
#
# Epoch 00007: val_loss improved from 38698.35365 to 37677.67225, saving model to Weights-007--37677.67225.hdf5
# Epoch 8/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 33950.2389 - mean_absolute_error: 33950.2389 - val_loss: 37124.7586 - val_mean_absolute_error: 37124.7586
#
# Epoch 00008: val_loss improved from 37677.67225 to 37124.75856, saving model to Weights-008--37124.75856.hdf5
# Epoch 9/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 33947.9889 - mean_absolute_error: 33947.9889 - val_loss: 35737.1116 - val_mean_absolute_error: 35737.1116
#
# Epoch 00009: val_loss improved from 37124.75856 to 35737.11157, saving model to Weights-009--35737.11157.hdf5
# Epoch 10/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 32769.9851 - mean_absolute_error: 32769.9851 - val_loss: 36221.7053 - val_mean_absolute_error: 36221.7053
#
# Epoch 00010: val_loss did not improve from 35737.11157
# Epoch 11/500
# 1168/1168 [==============================] - 0s 116us/step - loss: 32644.9767 - mean_absolute_error: 32644.9767 - val_loss: 35602.0479 - val_mean_absolute_error: 35602.0479
#
# Epoch 00011: val_loss improved from 35737.11157 to 35602.04795, saving model to Weights-011--35602.04795.hdf5
# Epoch 12/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 32254.1846 - mean_absolute_error: 32254.1846 - val_loss: 34967.7476 - val_mean_absolute_error: 34967.7476
#
# Epoch 00012: val_loss improved from 35602.04795 to 34967.74765, saving model to Weights-012--34967.74765.hdf5
# Epoch 13/500
# 1168/1168 [==============================] - 0s 115us/step - loss: 32173.3345 - mean_absolute_error: 32173.3345 - val_loss: 35102.2370 - val_mean_absolute_error: 35102.2370
#
# Epoch 00013: val_loss did not improve from 34967.74765
# Epoch 14/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 31771.9517 - mean_absolute_error: 31771.9517 - val_loss: 35859.8172 - val_mean_absolute_error: 35859.8172
#
# Epoch 00014: val_loss did not improve from 34967.74765
# Epoch 15/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 32001.6827 - mean_absolute_error: 32001.6827 - val_loss: 37401.8885 - val_mean_absolute_error: 37401.8885
#
# Epoch 00015: val_loss did not improve from 34967.74765
# Epoch 16/500
# 1168/1168 [==============================] - 0s 113us/step - loss: 32456.2451 - mean_absolute_error: 32456.2451 - val_loss: 37722.2741 - val_mean_absolute_error: 37722.2741
#
# Epoch 00016: val_loss did not improve from 34967.74765
# Epoch 17/500
# 1168/1168 [==============================] - 0s 116us/step - loss: 34517.0454 - mean_absolute_error: 34517.0454 - val_loss: 34588.1096 - val_mean_absolute_error: 34588.1096
#
# Epoch 00017: val_loss improved from 34967.74765 to 34588.10964, saving model to Weights-017--34588.10964.hdf5
# Epoch 18/500
# 1168/1168 [==============================] - 0s 115us/step - loss: 31300.0401 - mean_absolute_error: 31300.0401 - val_loss: 34672.4923 - val_mean_absolute_error: 34672.4923
#
# Epoch 00018: val_loss did not improve from 34588.10964
# Epoch 19/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 31309.3999 - mean_absolute_error: 31309.3999 - val_loss: 35047.7655 - val_mean_absolute_error: 35047.7655
#
# Epoch 00019: val_loss did not improve from 34588.10964
# Epoch 20/500
# 1168/1168 [==============================] - 0s 126us/step - loss: 31967.5743 - mean_absolute_error: 31967.5743 - val_loss: 34756.7124 - val_mean_absolute_error: 34756.7124
#
# Epoch 00020: val_loss did not improve from 34588.10964
# Epoch 21/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 31484.2809 - mean_absolute_error: 31484.2809 - val_loss: 34423.5525 - val_mean_absolute_error: 34423.5525
#
# Epoch 00021: val_loss improved from 34588.10964 to 34423.55249, saving model to Weights-021--34423.55249.hdf5
# Epoch 22/500
# 1168/1168 [==============================] - 0s 142us/step - loss: 31281.4994 - mean_absolute_error: 31281.4994 - val_loss: 36090.5374 - val_mean_absolute_error: 36090.5374
#
# Epoch 00022: val_loss did not improve from 34423.55249
# Epoch 23/500
# 1168/1168 [==============================] - 0s 161us/step - loss: 31937.9220 - mean_absolute_error: 31937.9220 - val_loss: 34870.7480 - val_mean_absolute_error: 34870.7480
#
# Epoch 00023: val_loss did not improve from 34423.55249
# Epoch 24/500
# 1168/1168 [==============================] - 0s 144us/step - loss: 32005.3041 - mean_absolute_error: 32005.3041 - val_loss: 34590.2089 - val_mean_absolute_error: 34590.2089
#
# Epoch 00024: val_loss did not improve from 34423.55249
# Epoch 25/500
# 1168/1168 [==============================] - 0s 136us/step - loss: 31106.3469 - mean_absolute_error: 31106.3469 - val_loss: 34492.0935 - val_mean_absolute_error: 34492.0935
#
# Epoch 00025: val_loss did not improve from 34423.55249
# Epoch 26/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 32562.7812 - mean_absolute_error: 32562.7812 - val_loss: 34236.4691 - val_mean_absolute_error: 34236.4691
#
# Epoch 00026: val_loss improved from 34423.55249 to 34236.46912, saving model to Weights-026--34236.46912.hdf5
# Epoch 27/500
# 1168/1168 [==============================] - 0s 129us/step - loss: 30711.1474 - mean_absolute_error: 30711.1474 - val_loss: 33851.3862 - val_mean_absolute_error: 33851.3862
#
# Epoch 00027: val_loss improved from 34236.46912 to 33851.38624, saving model to Weights-027--33851.38624.hdf5
# Epoch 28/500
# 1168/1168 [==============================] - 0s 126us/step - loss: 31373.7432 - mean_absolute_error: 31373.7432 - val_loss: 34216.7970 - val_mean_absolute_error: 34216.7970
#
# Epoch 00028: val_loss did not improve from 33851.38624
# Epoch 29/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 32525.0784 - mean_absolute_error: 32525.0784 - val_loss: 34247.5576 - val_mean_absolute_error: 34247.5576
#
# Epoch 00029: val_loss did not improve from 33851.38624
# Epoch 30/500
# 1168/1168 [==============================] - 0s 140us/step - loss: 31012.9860 - mean_absolute_error: 31012.9860 - val_loss: 38946.7766 - val_mean_absolute_error: 38946.7766
#
# Epoch 00030: val_loss did not improve from 33851.38624
# Epoch 31/500
# 1168/1168 [==============================] - 0s 139us/step - loss: 30940.2341 - mean_absolute_error: 30940.2341 - val_loss: 33722.9707 - val_mean_absolute_error: 33722.9707
#
# Epoch 00031: val_loss improved from 33851.38624 to 33722.97073, saving model to Weights-031--33722.97073.hdf5
# Epoch 32/500
# 1168/1168 [==============================] - 0s 139us/step - loss: 30573.7057 - mean_absolute_error: 30573.7057 - val_loss: 36874.7671 - val_mean_absolute_error: 36874.7671
#
# Epoch 00032: val_loss did not improve from 33722.97073
# Epoch 33/500
# 1168/1168 [==============================] - 0s 145us/step - loss: 30662.4310 - mean_absolute_error: 30662.4310 - val_loss: 34036.3927 - val_mean_absolute_error: 34036.3927
#
# Epoch 00033: val_loss did not improve from 33722.97073
# Epoch 34/500
# 1168/1168 [==============================] - 0s 141us/step - loss: 30364.0224 - mean_absolute_error: 30364.0224 - val_loss: 33921.7749 - val_mean_absolute_error: 33921.7749
#
# Epoch 00034: val_loss did not improve from 33722.97073
# Epoch 35/500
# 1168/1168 [==============================] - 0s 139us/step - loss: 30038.3182 - mean_absolute_error: 30038.3182 - val_loss: 33615.6858 - val_mean_absolute_error: 33615.6858
#
# Epoch 00035: val_loss improved from 33722.97073 to 33615.68579, saving model to Weights-035--33615.68579.hdf5
# Epoch 36/500
# 1168/1168 [==============================] - 0s 138us/step - loss: 31744.1405 - mean_absolute_error: 31744.1405 - val_loss: 34762.3832 - val_mean_absolute_error: 34762.3832
#
# Epoch 00036: val_loss did not improve from 33615.68579
# Epoch 37/500
# 1168/1168 [==============================] - 0s 140us/step - loss: 30176.8851 - mean_absolute_error: 30176.8851 - val_loss: 33588.4445 - val_mean_absolute_error: 33588.4445
#
# Epoch 00037: val_loss improved from 33615.68579 to 33588.44451, saving model to Weights-037--33588.44451.hdf5
# Epoch 38/500
# 1168/1168 [==============================] - 0s 144us/step - loss: 30663.3012 - mean_absolute_error: 30663.3012 - val_loss: 33956.0502 - val_mean_absolute_error: 33956.0502
#
# Epoch 00038: val_loss did not improve from 33588.44451
# Epoch 39/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 30761.6961 - mean_absolute_error: 30761.6961 - val_loss: 35129.1261 - val_mean_absolute_error: 35129.1261
#
# Epoch 00039: val_loss did not improve from 33588.44451
# Epoch 40/500
# 1168/1168 [==============================] - 0s 128us/step - loss: 30675.7944 - mean_absolute_error: 30675.7944 - val_loss: 34593.7496 - val_mean_absolute_error: 34593.7496
#
# Epoch 00040: val_loss did not improve from 33588.44451
# Epoch 41/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 30021.9544 - mean_absolute_error: 30021.9544 - val_loss: 34142.2344 - val_mean_absolute_error: 34142.2344
#
# Epoch 00041: val_loss did not improve from 33588.44451
# Epoch 42/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 30010.1722 - mean_absolute_error: 30010.1722 - val_loss: 34628.0154 - val_mean_absolute_error: 34628.0154
#
# Epoch 00042: val_loss did not improve from 33588.44451
# Epoch 43/500
# 1168/1168 [==============================] - 0s 131us/step - loss: 30967.9148 - mean_absolute_error: 30967.9148 - val_loss: 33228.8770 - val_mean_absolute_error: 33228.8770
#
# Epoch 00043: val_loss improved from 33588.44451 to 33228.87703, saving model to Weights-043--33228.87703.hdf5
# Epoch 44/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 30044.0341 - mean_absolute_error: 30044.0341 - val_loss: 35254.0109 - val_mean_absolute_error: 35254.0109
#
# Epoch 00044: val_loss did not improve from 33228.87703
# Epoch 45/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 29214.4722 - mean_absolute_error: 29214.4722 - val_loss: 32910.5108 - val_mean_absolute_error: 32910.5108
#
# Epoch 00045: val_loss improved from 33228.87703 to 32910.51076, saving model to Weights-045--32910.51076.hdf5
# Epoch 46/500
# 1168/1168 [==============================] - 0s 123us/step - loss: 30804.0585 - mean_absolute_error: 30804.0585 - val_loss: 32799.2458 - val_mean_absolute_error: 32799.2458
#
# Epoch 00046: val_loss improved from 32910.51076 to 32799.24577, saving model to Weights-046--32799.24577.hdf5
# Epoch 47/500
# 1168/1168 [==============================] - 0s 174us/step - loss: 29341.0665 - mean_absolute_error: 29341.0665 - val_loss: 33052.5742 - val_mean_absolute_error: 33052.5742
#
# Epoch 00047: val_loss did not improve from 32799.24577
# Epoch 48/500
# 1168/1168 [==============================] - 0s 145us/step - loss: 30028.3696 - mean_absolute_error: 30028.3696 - val_loss: 34352.0762 - val_mean_absolute_error: 34352.0762
#
# Epoch 00048: val_loss did not improve from 32799.24577
# Epoch 49/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 29659.1508 - mean_absolute_error: 29659.1508 - val_loss: 36474.5601 - val_mean_absolute_error: 36474.5601
#
# Epoch 00049: val_loss did not improve from 32799.24577
# Epoch 50/500
# 1168/1168 [==============================] - 0s 121us/step - loss: 29604.1315 - mean_absolute_error: 29604.1315 - val_loss: 35504.6887 - val_mean_absolute_error: 35504.6887
#
# Epoch 00050: val_loss did not improve from 32799.24577
# Epoch 51/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 29888.5149 - mean_absolute_error: 29888.5149 - val_loss: 32676.0417 - val_mean_absolute_error: 32676.0417
#
# Epoch 00051: val_loss improved from 32799.24577 to 32676.04174, saving model to Weights-051--32676.04174.hdf5
# Epoch 52/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 28630.7418 - mean_absolute_error: 28630.7418 - val_loss: 32656.2666 - val_mean_absolute_error: 32656.2666
#
# Epoch 00052: val_loss improved from 32676.04174 to 32656.26664, saving model to Weights-052--32656.26664.hdf5
# Epoch 53/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 28770.6446 - mean_absolute_error: 28770.6446 - val_loss: 34566.4287 - val_mean_absolute_error: 34566.4287
#
# Epoch 00053: val_loss did not improve from 32656.26664
# Epoch 54/500
# 1168/1168 [==============================] - 0s 123us/step - loss: 29681.9515 - mean_absolute_error: 29681.9515 - val_loss: 35000.7499 - val_mean_absolute_error: 35000.7499
#
# Epoch 00054: val_loss did not improve from 32656.26664
# Epoch 55/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 29311.7056 - mean_absolute_error: 29311.7056 - val_loss: 33928.0860 - val_mean_absolute_error: 33928.0860
#
# Epoch 00055: val_loss did not improve from 32656.26664
# Epoch 56/500
# 1168/1168 [==============================] - 0s 139us/step - loss: 29346.7486 - mean_absolute_error: 29346.7486 - val_loss: 31673.7769 - val_mean_absolute_error: 31673.7769
#
# Epoch 00056: val_loss improved from 32656.26664 to 31673.77692, saving model to Weights-056--31673.77692.hdf5
# Epoch 57/500
# 1168/1168 [==============================] - 0s 182us/step - loss: 28605.6395 - mean_absolute_error: 28605.6395 - val_loss: 32222.1809 - val_mean_absolute_error: 32222.1809
#
# Epoch 00057: val_loss did not improve from 31673.77692
# Epoch 58/500
# 1168/1168 [==============================] - 0s 136us/step - loss: 29621.7374 - mean_absolute_error: 29621.7374 - val_loss: 31656.7382 - val_mean_absolute_error: 31656.7382
#
# Epoch 00058: val_loss improved from 31673.77692 to 31656.73823, saving model to Weights-058--31656.73823.hdf5
# Epoch 59/500
# 1168/1168 [==============================] - 0s 135us/step - loss: 29251.8725 - mean_absolute_error: 29251.8725 - val_loss: 32198.9336 - val_mean_absolute_error: 32198.9336
#
# Epoch 00059: val_loss did not improve from 31656.73823
# Epoch 60/500
# 1168/1168 [==============================] - 0s 183us/step - loss: 28601.6908 - mean_absolute_error: 28601.6908 - val_loss: 33534.5650 - val_mean_absolute_error: 33534.5650
#
# Epoch 00060: val_loss did not improve from 31656.73823
# Epoch 61/500
# 1168/1168 [==============================] - 0s 131us/step - loss: 28693.3824 - mean_absolute_error: 28693.3824 - val_loss: 34606.0323 - val_mean_absolute_error: 34606.0323
# Epoch 00061: val_loss did not improve from 31656.73823
# Epoch 62/500
# 1168/1168 [==============================] - 0s 112us/step - loss: 28455.8342 - mean_absolute_error: 28455.8342 - val_loss: 34987.1566 - val_mean_absolute_error: 34987.1566
#
# Epoch 00062: val_loss did not improve from 31656.73823
# Epoch 63/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 28669.7639 - mean_absolute_error: 28669.7639 - val_loss: 31495.1969 - val_mean_absolute_error: 31495.1969
#
# Epoch 00063: val_loss improved from 31656.73823 to 31495.19692, saving model to Weights-063--31495.19692.hdf5
# Epoch 64/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 28899.5992 - mean_absolute_error: 28899.5992 - val_loss: 31053.7097 - val_mean_absolute_error: 31053.7097
#
# Epoch 00064: val_loss improved from 31495.19692 to 31053.70971, saving model to Weights-064--31053.70971.hdf5
# Epoch 65/500
# 1168/1168 [==============================] - 0s 112us/step - loss: 27787.4739 - mean_absolute_error: 27787.4739 - val_loss: 31866.8131 - val_mean_absolute_error: 31866.8131
#
# Epoch 00065: val_loss did not improve from 31053.70971
# Epoch 66/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 27870.7516 - mean_absolute_error: 27870.7516 - val_loss: 31427.7562 - val_mean_absolute_error: 31427.7562
#
# Epoch 00066: val_loss did not improve from 31053.70971
# Epoch 67/500
# 1168/1168 [==============================] - 0s 109us/step - loss: 28186.4849 - mean_absolute_error: 28186.4849 - val_loss: 32058.0002 - val_mean_absolute_error: 32058.0002
#
# Epoch 00067: val_loss did not improve from 31053.70971
# Epoch 68/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 27836.2124 - mean_absolute_error: 27836.2124 - val_loss: 31179.3129 - val_mean_absolute_error: 31179.3129
#
# Epoch 00068: val_loss did not improve from 31053.70971
# Epoch 69/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 27479.4127 - mean_absolute_error: 27479.4127 - val_loss: 32297.0938 - val_mean_absolute_error: 32297.0938
#
# Epoch 00069: val_loss did not improve from 31053.70971
# Epoch 70/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 27394.5865 - mean_absolute_error: 27394.5865 - val_loss: 31332.6984 - val_mean_absolute_error: 31332.6984
#
# Epoch 00070: val_loss did not improve from 31053.70971
# Epoch 71/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 27630.8287 - mean_absolute_error: 27630.8287 - val_loss: 33651.2052 - val_mean_absolute_error: 33651.2052
#
# Epoch 00071: val_loss did not improve from 31053.70971
# Epoch 72/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 28226.4334 - mean_absolute_error: 28226.4334 - val_loss: 32642.0144 - val_mean_absolute_error: 32642.0144
#
# Epoch 00072: val_loss did not improve from 31053.70971
# Epoch 73/500
# 1168/1168 [==============================] - 0s 109us/step - loss: 30527.8339 - mean_absolute_error: 30527.8339 - val_loss: 31169.1980 - val_mean_absolute_error: 31169.1980
#
# Epoch 00073: val_loss did not improve from 31053.70971
# Epoch 74/500
# 1168/1168 [==============================] - 0s 119us/step - loss: 27541.3108 - mean_absolute_error: 27541.3108 - val_loss: 33957.1280 - val_mean_absolute_error: 33957.1280
#
# Epoch 00074: val_loss did not improve from 31053.70971
# Epoch 75/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 27040.5621 - mean_absolute_error: 27040.5621 - val_loss: 29982.9133 - val_mean_absolute_error: 29982.9133
#
# Epoch 00075: val_loss improved from 31053.70971 to 29982.91326, saving model to Weights-075--29982.91326.hdf5
# Epoch 76/500
# 1168/1168 [==============================] - 0s 130us/step - loss: 26649.3372 - mean_absolute_error: 26649.3372 - val_loss: 31069.2935 - val_mean_absolute_error: 31069.2935
#
# Epoch 00076: val_loss did not improve from 29982.91326
# Epoch 77/500
# 1168/1168 [==============================] - 0s 147us/step - loss: 27078.2092 - mean_absolute_error: 27078.2092 - val_loss: 30679.9760 - val_mean_absolute_error: 30679.9760
#
# Epoch 00077: val_loss did not improve from 29982.91326
# Epoch 78/500
# 1168/1168 [==============================] - 0s 136us/step - loss: 26932.2865 - mean_absolute_error: 26932.2865 - val_loss: 33157.6691 - val_mean_absolute_error: 33157.6691
#
# Epoch 00078: val_loss did not improve from 29982.91326
# Epoch 79/500
# 1168/1168 [==============================] - 0s 168us/step - loss: 27336.9102 - mean_absolute_error: 27336.9102 - val_loss: 32385.9636 - val_mean_absolute_error: 32385.9636
#
# Epoch 00079: val_loss did not improve from 29982.91326
# Epoch 80/500
# 1168/1168 [==============================] - 0s 137us/step - loss: 27862.3203 - mean_absolute_error: 27862.3203 - val_loss: 32467.5479 - val_mean_absolute_error: 32467.5479
#
# Epoch 00080: val_loss did not improve from 29982.91326
# Epoch 81/500
# 1168/1168 [==============================] - 0s 114us/step - loss: 27722.5306 - mean_absolute_error: 27722.5306 - val_loss: 34340.2919 - val_mean_absolute_error: 34340.2919
#
# Epoch 00081: val_loss did not improve from 29982.91326
# Epoch 82/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 27521.9454 - mean_absolute_error: 27521.9454 - val_loss: 29364.1701 - val_mean_absolute_error: 29364.1701
#
# Epoch 00082: val_loss improved from 29982.91326 to 29364.17006, saving model to Weights-082--29364.17006.hdf5
# Epoch 83/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 26763.2247 - mean_absolute_error: 26763.2247 - val_loss: 29552.4126 - val_mean_absolute_error: 29552.4126
#
# Epoch 00083: val_loss did not improve from 29364.17006
# Epoch 84/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 25729.8980 - mean_absolute_error: 25729.8980 - val_loss: 29219.6249 - val_mean_absolute_error: 29219.6249
#
# Epoch 00084: val_loss improved from 29364.17006 to 29219.62495, saving model to Weights-084--29219.62495.hdf5
# Epoch 85/500
# 1168/1168 [==============================] - 0s 115us/step - loss: 25669.5509 - mean_absolute_error: 25669.5509 - val_loss: 30087.9820 - val_mean_absolute_error: 30087.9820
#
# Epoch 00085: val_loss did not improve from 29219.62495
# Epoch 86/500
# 1168/1168 [==============================] - 0s 112us/step - loss: 26058.4405 - mean_absolute_error: 26058.4405 - val_loss: 29759.4456 - val_mean_absolute_error: 29759.4456
#
# Epoch 00086: val_loss did not improve from 29219.62495
# Epoch 87/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 25627.7039 - mean_absolute_error: 25627.7039 - val_loss: 33594.9622 - val_mean_absolute_error: 33594.9622
#
# Epoch 00087: val_loss did not improve from 29219.62495
# Epoch 88/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 26356.1699 - mean_absolute_error: 26356.1699 - val_loss: 35818.5936 - val_mean_absolute_error: 35818.5936
#
# Epoch 00088: val_loss did not improve from 29219.62495
# Epoch 89/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 28463.9092 - mean_absolute_error: 28463.9092 - val_loss: 28660.0679 - val_mean_absolute_error: 28660.0679
#
# Epoch 00089: val_loss improved from 29219.62495 to 28660.06785, saving model to Weights-089--28660.06785.hdf5
# Epoch 90/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 25609.9100 - mean_absolute_error: 25609.9100 - val_loss: 28994.9059 - val_mean_absolute_error: 28994.9059
#
# Epoch 00090: val_loss did not improve from 28660.06785
# Epoch 91/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 25985.2751 - mean_absolute_error: 25985.2751 - val_loss: 29621.1193 - val_mean_absolute_error: 29621.1193
#
# Epoch 00091: val_loss did not improve from 28660.06785
# Epoch 92/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 27368.5464 - mean_absolute_error: 27368.5464 - val_loss: 27943.1155 - val_mean_absolute_error: 27943.1155
#
# Epoch 00092: val_loss improved from 28660.06785 to 27943.11548, saving model to Weights-092--27943.11548.hdf5
# Epoch 93/500
# 1168/1168 [==============================] - 0s 112us/step - loss: 25154.4525 - mean_absolute_error: 25154.4525 - val_loss: 30474.2956 - val_mean_absolute_error: 30474.2956
#
# Epoch 00093: val_loss did not improve from 27943.11548
# Epoch 94/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 25251.9242 - mean_absolute_error: 25251.9242 - val_loss: 29573.7891 - val_mean_absolute_error: 29573.7891
#
# Epoch 00094: val_loss did not improve from 27943.11548
# Epoch 95/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 25273.9561 - mean_absolute_error: 25273.9561 - val_loss: 28835.5364 - val_mean_absolute_error: 28835.5364
#
# Epoch 00095: val_loss did not improve from 27943.11548
# Epoch 96/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 25284.3162 - mean_absolute_error: 25284.3162 - val_loss: 28689.9514 - val_mean_absolute_error: 28689.9514
#
# Epoch 00096: val_loss did not improve from 27943.11548
# Epoch 97/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 25217.6062 - mean_absolute_error: 25217.6062 - val_loss: 29019.9623 - val_mean_absolute_error: 29019.9623
#
# Epoch 00097: val_loss did not improve from 27943.11548
# Epoch 98/500
# 1168/1168 [==============================] - 0s 98us/step - loss: 23897.2671 - mean_absolute_error: 23897.2671 - val_loss: 28887.5641 - val_mean_absolute_error: 28887.5641
#
# Epoch 00098: val_loss did not improve from 27943.11548
# Epoch 99/500
# 1168/1168 [==============================] - 0s 94us/step - loss: 24811.6707 - mean_absolute_error: 24811.6707 - val_loss: 29217.2176 - val_mean_absolute_error: 29217.2176
#
# Epoch 00099: val_loss did not improve from 27943.11548
# Epoch 100/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 25342.6240 - mean_absolute_error: 25342.6240 - val_loss: 29886.7861 - val_mean_absolute_error: 29886.7861
#
# Epoch 00100: val_loss did not improve from 27943.11548
# Epoch 101/500
# 1168/1168 [==============================] - 0s 94us/step - loss: 23866.0234 - mean_absolute_error: 23866.0234 - val_loss: 27455.5435 - val_mean_absolute_error: 27455.5435
#
# Epoch 00101: val_loss improved from 27943.11548 to 27455.54345, saving model to Weights-101--27455.54345.hdf5
# Epoch 102/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 23591.3247 - mean_absolute_error: 23591.3247 - val_loss: 27415.7432 - val_mean_absolute_error: 27415.7432
#
# Epoch 00102: val_loss improved from 27455.54345 to 27415.74320, saving model to Weights-102--27415.74320.hdf5
# Epoch 103/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 24589.2954 - mean_absolute_error: 24589.2954 - val_loss: 28120.6862 - val_mean_absolute_error: 28120.6862
#
# Epoch 00103: val_loss did not improve from 27415.74320
# Epoch 104/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 24673.9971 - mean_absolute_error: 24673.9971 - val_loss: 26957.3066 - val_mean_absolute_error: 26957.3066
#
# Epoch 00104: val_loss improved from 27415.74320 to 26957.30661, saving model to Weights-104--26957.30661.hdf5
# Epoch 105/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 24318.1231 - mean_absolute_error: 24318.1231 - val_loss: 28001.4918 - val_mean_absolute_error: 28001.4918
#
# Epoch 00105: val_loss did not improve from 26957.30661
# Epoch 106/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 24607.0268 - mean_absolute_error: 24607.0268 - val_loss: 29409.4168 - val_mean_absolute_error: 29409.4168
#
# Epoch 00106: val_loss did not improve from 26957.30661
# Epoch 107/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 23082.4019 - mean_absolute_error: 23082.4019 - val_loss: 27235.7761 - val_mean_absolute_error: 27235.7761
#
# Epoch 00107: val_loss did not improve from 26957.30661
# Epoch 108/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 24303.3973 - mean_absolute_error: 24303.3973 - val_loss: 27722.2679 - val_mean_absolute_error: 27722.2679
#
# Epoch 00108: val_loss did not improve from 26957.30661
# Epoch 109/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 23150.1127 - mean_absolute_error: 23150.1127 - val_loss: 26138.6001 - val_mean_absolute_error: 26138.6001
#
# Epoch 00109: val_loss improved from 26957.30661 to 26138.60006, saving model to Weights-109--26138.60006.hdf5
# Epoch 110/500
# 1168/1168 [==============================] - 0s 129us/step - loss: 23454.7370 - mean_absolute_error: 23454.7370 - val_loss: 26512.9161 - val_mean_absolute_error: 26512.9161
#
# Epoch 00110: val_loss did not improve from 26138.60006
# Epoch 111/500
# 1168/1168 [==============================] - 0s 126us/step - loss: 22554.0111 - mean_absolute_error: 22554.0111 - val_loss: 28828.4738 - val_mean_absolute_error: 28828.4738
#
# Epoch 00111: val_loss did not improve from 26138.60006
# Epoch 112/500
# 1168/1168 [==============================] - 0s 123us/step - loss: 23141.7971 - mean_absolute_error: 23141.7971 - val_loss: 26311.0989 - val_mean_absolute_error: 26311.0989
#
# Epoch 00112: val_loss did not improve from 26138.60006
# Epoch 113/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 24027.4381 - mean_absolute_error: 24027.4381 - val_loss: 25824.1208 - val_mean_absolute_error: 25824.1208
#
# Epoch 00113: val_loss improved from 26138.60006 to 25824.12083, saving model to Weights-113--25824.12083.hdf5
# Epoch 114/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 22072.8927 - mean_absolute_error: 22072.8927 - val_loss: 26231.8767 - val_mean_absolute_error: 26231.8767
#
# Epoch 00114: val_loss did not improve from 25824.12083
# Epoch 115/500
# 1168/1168 [==============================] - 0s 94us/step - loss: 21979.9553 - mean_absolute_error: 21979.9553 - val_loss: 30395.6579 - val_mean_absolute_error: 30395.6579
#
# Epoch 00115: val_loss did not improve from 25824.12083
# Epoch 116/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 22788.8030 - mean_absolute_error: 22788.8030 - val_loss: 28305.3482 - val_mean_absolute_error: 28305.3482
#
# Epoch 00116: val_loss did not improve from 25824.12083
# Epoch 117/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 22797.6523 - mean_absolute_error: 22797.6523 - val_loss: 33754.0793 - val_mean_absolute_error: 33754.0793
#
# Epoch 00117: val_loss did not improve from 25824.12083
# Epoch 118/500
# 1168/1168 [==============================] - 0s 98us/step - loss: 24456.3827 - mean_absolute_error: 24456.3827 - val_loss: 27076.0390 - val_mean_absolute_error: 27076.0390
#
# Epoch 00118: val_loss did not improve from 25824.12083
# Epoch 119/500
# 1168/1168 [==============================] - 0s 99us/step - loss: 22287.7983 - mean_absolute_error: 22287.7983 - val_loss: 25854.8461 - val_mean_absolute_error: 25854.8461
#
# Epoch 00119: val_loss did not improve from 25824.12083
# Epoch 120/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 22386.2311 - mean_absolute_error: 22386.2311 - val_loss: 25794.1651 - val_mean_absolute_error: 25794.1651
#
# Epoch 00120: val_loss improved from 25824.12083 to 25794.16513, saving model to Weights-120--25794.16513.hdf5
# Epoch 121/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 21735.3884 - mean_absolute_error: 21735.3884 - val_loss: 26640.0378 - val_mean_absolute_error: 26640.0378
#
# Epoch 00121: val_loss did not improve from 25794.16513
# Epoch 122/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 22250.1856 - mean_absolute_error: 22250.1856 - val_loss: 25574.8886 - val_mean_absolute_error: 25574.8886
#
# Epoch 00122: val_loss improved from 25794.16513 to 25574.88865, saving model to Weights-122--25574.88865.hdf5
# Epoch 123/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 21723.0086 - mean_absolute_error: 21723.0086 - val_loss: 26243.6157 - val_mean_absolute_error: 26243.6157
#
# Epoch 00123: val_loss did not improve from 25574.88865
# Epoch 124/500
# 1168/1168 [==============================] - 0s 119us/step - loss: 20910.6176 - mean_absolute_error: 20910.6176 - val_loss: 26794.9822 - val_mean_absolute_error: 26794.9822
#
# Epoch 00124: val_loss did not improve from 25574.88865
# Epoch 125/500
# 1168/1168 [==============================] - 0s 114us/step - loss: 22350.8570 - mean_absolute_error: 22350.8570 - val_loss: 25332.6083 - val_mean_absolute_error: 25332.6083
#
# Epoch 00125: val_loss improved from 25574.88865 to 25332.60830, saving model to Weights-125--25332.60830.hdf5
# Epoch 126/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 22496.2154 - mean_absolute_error: 22496.2154 - val_loss: 26124.4640 - val_mean_absolute_error: 26124.4640
#
# Epoch 00126: val_loss did not improve from 25332.60830
# Epoch 127/500
# 1168/1168 [==============================] - 0s 96us/step - loss: 21596.4395 - mean_absolute_error: 21596.4395 - val_loss: 25818.0523 - val_mean_absolute_error: 25818.0523
#
# Epoch 00127: val_loss did not improve from 25332.60830
# Epoch 128/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 20722.4837 - mean_absolute_error: 20722.4837 - val_loss: 24707.7746 - val_mean_absolute_error: 24707.7746
#
# Epoch 00128: val_loss improved from 25332.60830 to 24707.77456, saving model to Weights-128--24707.77456.hdf5
# Epoch 129/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 20820.2135 - mean_absolute_error: 20820.2135 - val_loss: 24943.0385 - val_mean_absolute_error: 24943.0385
#
# Epoch 00129: val_loss did not improve from 24707.77456
# Epoch 130/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 21032.4034 - mean_absolute_error: 21032.4034 - val_loss: 24830.5601 - val_mean_absolute_error: 24830.5601
#
# Epoch 00130: val_loss did not improve from 24707.77456
# Epoch 131/500
# 1168/1168 [==============================] - 0s 116us/step - loss: 22534.5947 - mean_absolute_error: 22534.5947 - val_loss: 25934.8638 - val_mean_absolute_error: 25934.8638
#
# Epoch 00131: val_loss did not improve from 24707.77456
# Epoch 132/500
# 1168/1168 [==============================] - 0s 99us/step - loss: 21429.0236 - mean_absolute_error: 21429.0236 - val_loss: 24253.9315 - val_mean_absolute_error: 24253.9315
#
# Epoch 00132: val_loss improved from 24707.77456 to 24253.93145, saving model to Weights-132--24253.93145.hdf5
# Epoch 133/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 20265.0978 - mean_absolute_error: 20265.0978 - val_loss: 24849.7263 - val_mean_absolute_error: 24849.7263
#
# Epoch 00133: val_loss did not improve from 24253.93145
# Epoch 134/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 19814.4802 - mean_absolute_error: 19814.4802 - val_loss: 24297.3218 - val_mean_absolute_error: 24297.3218
#
# Epoch 00134: val_loss did not improve from 24253.93145
# Epoch 135/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 20720.4726 - mean_absolute_error: 20720.4726 - val_loss: 23871.6491 - val_mean_absolute_error: 23871.6491
#
# Epoch 00135: val_loss improved from 24253.93145 to 23871.64913, saving model to Weights-135--23871.64913.hdf5
# Epoch 136/500
# 1168/1168 [==============================] - 0s 111us/step - loss: 20455.3098 - mean_absolute_error: 20455.3098 - val_loss: 25435.3468 - val_mean_absolute_error: 25435.3468
#
# Epoch 00136: val_loss did not improve from 23871.64913
# Epoch 137/500
# 1168/1168 [==============================] - 0s 100us/step - loss: 20543.5761 - mean_absolute_error: 20543.5761 - val_loss: 26960.2969 - val_mean_absolute_error: 26960.2969
#
# Epoch 00137: val_loss did not improve from 23871.64913
# Epoch 138/500
# 1168/1168 [==============================] - 0s 100us/step - loss: 19634.2008 - mean_absolute_error: 19634.2008 - val_loss: 24352.2913 - val_mean_absolute_error: 24352.2913
#
# Epoch 00138: val_loss did not improve from 23871.64913
# Epoch 139/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 19916.2728 - mean_absolute_error: 19916.2728 - val_loss: 23558.5673 - val_mean_absolute_error: 23558.5673
#
# Epoch 00139: val_loss improved from 23871.64913 to 23558.56726, saving model to Weights-139--23558.56726.hdf5
# Epoch 140/500
# 1168/1168 [==============================] - 0s 100us/step - loss: 21684.1386 - mean_absolute_error: 21684.1386 - val_loss: 26661.0461 - val_mean_absolute_error: 26661.0461
#
# Epoch 00140: val_loss did not improve from 23558.56726
# Epoch 141/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 21313.6070 - mean_absolute_error: 21313.6070 - val_loss: 24456.6670 - val_mean_absolute_error: 24456.6670
#
# Epoch 00141: val_loss did not improve from 23558.56726
# Epoch 142/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 24088.4823 - mean_absolute_error: 24088.4823 - val_loss: 26145.8518 - val_mean_absolute_error: 26145.8518
#
# Epoch 00142: val_loss did not improve from 23558.56726
# Epoch 143/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 21844.7814 - mean_absolute_error: 21844.7814 - val_loss: 25591.1847 - val_mean_absolute_error: 25591.1847
#
# Epoch 00143: val_loss did not improve from 23558.56726
# Epoch 144/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 19751.8487 - mean_absolute_error: 19751.8487 - val_loss: 23828.3283 - val_mean_absolute_error: 23828.3283
#
# Epoch 00144: val_loss did not improve from 23558.56726
# Epoch 145/500
# 1168/1168 [==============================] - 0s 111us/step - loss: 19891.0709 - mean_absolute_error: 19891.0709 - val_loss: 28183.2365 - val_mean_absolute_error: 28183.2365
#
# Epoch 00145: val_loss did not improve from 23558.56726
# Epoch 146/500
# 1168/1168 [==============================] - 0s 95us/step - loss: 23781.8192 - mean_absolute_error: 23781.8192 - val_loss: 25348.8799 - val_mean_absolute_error: 25348.8799
#
# Epoch 00146: val_loss did not improve from 23558.56726
# Epoch 147/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 25121.7546 - mean_absolute_error: 25121.7546 - val_loss: 25389.7971 - val_mean_absolute_error: 25389.7971
#
# Epoch 00147: val_loss did not improve from 23558.56726
# Epoch 148/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 21029.8030 - mean_absolute_error: 21029.8030 - val_loss: 24668.3198 - val_mean_absolute_error: 24668.3198
#
# Epoch 00148: val_loss did not improve from 23558.56726
# Epoch 149/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 23443.2308 - mean_absolute_error: 23443.2308 - val_loss: 25114.9727 - val_mean_absolute_error: 25114.9727
#
# Epoch 00149: val_loss did not improve from 23558.56726
# Epoch 150/500
# 1168/1168 [==============================] - 0s 133us/step - loss: 19607.3033 - mean_absolute_error: 19607.3033 - val_loss: 26653.1472 - val_mean_absolute_error: 26653.1472
#
# Epoch 00150: val_loss did not improve from 23558.56726
# Epoch 151/500
# 1168/1168 [==============================] - 0s 131us/step - loss: 19768.5480 - mean_absolute_error: 19768.5480 - val_loss: 23582.5092 - val_mean_absolute_error: 23582.5092
#
# Epoch 00151: val_loss did not improve from 23558.56726
# Epoch 152/500
# 1168/1168 [==============================] - 0s 116us/step - loss: 19714.2959 - mean_absolute_error: 19714.2959 - val_loss: 24985.6419 - val_mean_absolute_error: 24985.6419
#
# Epoch 00152: val_loss did not improve from 23558.56726
# Epoch 153/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 19778.9743 - mean_absolute_error: 19778.9743 - val_loss: 24579.1859 - val_mean_absolute_error: 24579.1859
#
# Epoch 00153: val_loss did not improve from 23558.56726
# Epoch 154/500
# 1168/1168 [==============================] - 0s 112us/step - loss: 19180.3221 - mean_absolute_error: 19180.3221 - val_loss: 24502.9089 - val_mean_absolute_error: 24502.9089
#
# Epoch 00154: val_loss did not improve from 23558.56726
# Epoch 155/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 19222.3563 - mean_absolute_error: 19222.3563 - val_loss: 23256.8076 - val_mean_absolute_error: 23256.8076
#
# Epoch 00155: val_loss improved from 23558.56726 to 23256.80758, saving model to Weights-155--23256.80758.hdf5
# Epoch 156/500
# 1168/1168 [==============================] - 0s 109us/step - loss: 19696.8943 - mean_absolute_error: 19696.8943 - val_loss: 24197.9744 - val_mean_absolute_error: 24197.9744
#
# Epoch 00156: val_loss did not improve from 23256.80758
# Epoch 157/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 19466.8960 - mean_absolute_error: 19466.8960 - val_loss: 23678.8309 - val_mean_absolute_error: 23678.8309
#
# Epoch 00157: val_loss did not improve from 23256.80758
# Epoch 158/500
# 1168/1168 [==============================] - 0s 114us/step - loss: 19367.9297 - mean_absolute_error: 19367.9297 - val_loss: 25047.7007 - val_mean_absolute_error: 25047.7007
# Epoch 00158: val_loss did not improve from 23256.80758
# Epoch 159/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 19583.2055 - mean_absolute_error: 19583.2055 - val_loss: 24356.3682 - val_mean_absolute_error: 24356.3682
#
# Epoch 00159: val_loss did not improve from 23256.80758
# Epoch 160/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 20455.0427 - mean_absolute_error: 20455.0427 - val_loss: 23290.1489 - val_mean_absolute_error: 23290.1489
#
# Epoch 00160: val_loss did not improve from 23256.80758
# Epoch 161/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 20039.7839 - mean_absolute_error: 20039.7839 - val_loss: 23070.2577 - val_mean_absolute_error: 23070.2577
#
# Epoch 00161: val_loss improved from 23256.80758 to 23070.25765, saving model to Weights-161--23070.25765.hdf5
# Epoch 162/500
# 1168/1168 [==============================] - 0s 125us/step - loss: 19615.6632 - mean_absolute_error: 19615.6632 - val_loss: 27023.9181 - val_mean_absolute_error: 27023.9181
#
# Epoch 00162: val_loss did not improve from 23070.25765
# Epoch 163/500
# 1168/1168 [==============================] - 0s 114us/step - loss: 19761.7455 - mean_absolute_error: 19761.7455 - val_loss: 23914.0476 - val_mean_absolute_error: 23914.0476
#
# Epoch 00163: val_loss did not improve from 23070.25765
# Epoch 164/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 19472.9963 - mean_absolute_error: 19472.9963 - val_loss: 26148.3872 - val_mean_absolute_error: 26148.3872
#
# Epoch 00164: val_loss did not improve from 23070.25765
# Epoch 165/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 20020.1847 - mean_absolute_error: 20020.1847 - val_loss: 26625.7094 - val_mean_absolute_error: 26625.7094
#
# Epoch 00165: val_loss did not improve from 23070.25765
# Epoch 166/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 21369.8464 - mean_absolute_error: 21369.8464 - val_loss: 23937.1552 - val_mean_absolute_error: 23937.1552
#
# Epoch 00166: val_loss did not improve from 23070.25765
# Epoch 167/500
# 1168/1168 [==============================] - 0s 170us/step - loss: 19985.4183 - mean_absolute_error: 19985.4183 - val_loss: 26929.6253 - val_mean_absolute_error: 26929.6253
#
# Epoch 00167: val_loss did not improve from 23070.25765
# Epoch 168/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 20340.9118 - mean_absolute_error: 20340.9118 - val_loss: 23167.3650 - val_mean_absolute_error: 23167.3650
#
# Epoch 00168: val_loss did not improve from 23070.25765
# Epoch 169/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 20087.3667 - mean_absolute_error: 20087.3667 - val_loss: 23269.0855 - val_mean_absolute_error: 23269.0855
#
# Epoch 00169: val_loss did not improve from 23070.25765
# Epoch 170/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 20437.3097 - mean_absolute_error: 20437.3097 - val_loss: 24545.6618 - val_mean_absolute_error: 24545.6618
#
# Epoch 00170: val_loss did not improve from 23070.25765
# Epoch 171/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 20966.0939 - mean_absolute_error: 20966.0939 - val_loss: 23070.0067 - val_mean_absolute_error: 23070.0067
#
# Epoch 00171: val_loss improved from 23070.25765 to 23070.00669, saving model to Weights-171--23070.00669.hdf5
# Epoch 172/500
# 1168/1168 [==============================] - 0s 129us/step - loss: 20133.7517 - mean_absolute_error: 20133.7517 - val_loss: 30409.5425 - val_mean_absolute_error: 30409.5425
#
# Epoch 00172: val_loss did not improve from 23070.00669
# Epoch 173/500
# 1168/1168 [==============================] - 0s 167us/step - loss: 19132.5249 - mean_absolute_error: 19132.5249 - val_loss: 25065.0341 - val_mean_absolute_error: 25065.0341
#
# Epoch 00173: val_loss did not improve from 23070.00669
# Epoch 174/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 20074.6927 - mean_absolute_error: 20074.6927 - val_loss: 22742.5848 - val_mean_absolute_error: 22742.5848
#
# Epoch 00174: val_loss improved from 23070.00669 to 22742.58481, saving model to Weights-174--22742.58481.hdf5
# Epoch 175/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 20125.9381 - mean_absolute_error: 20125.9381 - val_loss: 24349.8786 - val_mean_absolute_error: 24349.8786
#
# Epoch 00175: val_loss did not improve from 22742.58481
# Epoch 176/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 19464.4057 - mean_absolute_error: 19464.4057 - val_loss: 23408.3508 - val_mean_absolute_error: 23408.3508
#
# Epoch 00176: val_loss did not improve from 22742.58481
# Epoch 177/500
# 1168/1168 [==============================] - 0s 121us/step - loss: 20496.9163 - mean_absolute_error: 20496.9163 - val_loss: 24011.6772 - val_mean_absolute_error: 24011.6772
#
# Epoch 00177: val_loss did not improve from 22742.58481
# Epoch 178/500
# 1168/1168 [==============================] - 0s 120us/step - loss: 18516.2656 - mean_absolute_error: 18516.2656 - val_loss: 23745.7372 - val_mean_absolute_error: 23745.7372
#
# Epoch 00178: val_loss did not improve from 22742.58481
# Epoch 179/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 18496.0582 - mean_absolute_error: 18496.0582 - val_loss: 25892.7385 - val_mean_absolute_error: 25892.7385
#
# Epoch 00179: val_loss did not improve from 22742.58481
# Epoch 180/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 18053.6238 - mean_absolute_error: 18053.6238 - val_loss: 25587.7163 - val_mean_absolute_error: 25587.7163
#
# Epoch 00180: val_loss did not improve from 22742.58481
# Epoch 181/500
# 1168/1168 [==============================] - 0s 109us/step - loss: 18153.6951 - mean_absolute_error: 18153.6951 - val_loss: 23284.8206 - val_mean_absolute_error: 23284.8206
#
# Epoch 00181: val_loss did not improve from 22742.58481
# Epoch 182/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 18609.3801 - mean_absolute_error: 18609.3801 - val_loss: 22934.1362 - val_mean_absolute_error: 22934.1362
#
# Epoch 00182: val_loss did not improve from 22742.58481
# Epoch 183/500
# 1168/1168 [==============================] - 0s 113us/step - loss: 18965.7371 - mean_absolute_error: 18965.7371 - val_loss: 23326.3104 - val_mean_absolute_error: 23326.3104
#
# Epoch 00183: val_loss did not improve from 22742.58481
# Epoch 184/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 18086.3993 - mean_absolute_error: 18086.3993 - val_loss: 23108.1925 - val_mean_absolute_error: 23108.1925
#
# Epoch 00184: val_loss did not improve from 22742.58481
# Epoch 185/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 18125.4354 - mean_absolute_error: 18125.4354 - val_loss: 23220.7650 - val_mean_absolute_error: 23220.7650
#
# Epoch 00185: val_loss did not improve from 22742.58481
# Epoch 186/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 19431.2186 - mean_absolute_error: 19431.2186 - val_loss: 33421.3020 - val_mean_absolute_error: 33421.3020
#
# Epoch 00186: val_loss did not improve from 22742.58481
# Epoch 187/500
# ...
#
# Epoch 00435: val_loss did not improve from 19515.97544
# Epoch 436/500
# 1168/1168 [==============================] - 0s 121us/step - loss: 15899.9374 - mean_absolute_error: 15899.9374 - val_loss: 22292.6192 - val_mean_absolute_error: 22292.6192
#
# Epoch 00436: val_loss did not improve from 19515.97544
# Epoch 437/500
# 1168/1168 [==============================] - 0s 143us/step - loss: 15531.8820 - mean_absolute_error: 15531.8820 - val_loss: 20310.5332 - val_mean_absolute_error: 20310.5332
#
# Epoch 00437: val_loss did not improve from 19515.97544
# Epoch 438/500
# 1168/1168 [==============================] - 0s 176us/step - loss: 13984.0743 - mean_absolute_error: 13984.0743 - val_loss: 24858.0415 - val_mean_absolute_error: 24858.0415
#
# Epoch 00438: val_loss did not improve from 19515.97544
# Epoch 439/500
# 1168/1168 [==============================] - 0s 133us/step - loss: 15277.5778 - mean_absolute_error: 15277.5778 - val_loss: 21995.8990 - val_mean_absolute_error: 21995.8990
#
# Epoch 00439: val_loss did not improve from 19515.97544
# Epoch 440/500
# 1168/1168 [==============================] - 0s 142us/step - loss: 14616.2247 - mean_absolute_error: 14616.2247 - val_loss: 22993.5690 - val_mean_absolute_error: 22993.5690
#
# Epoch 00440: val_loss did not improve from 19515.97544
# Epoch 441/500
# 1168/1168 [==============================] - 0s 168us/step - loss: 13896.3781 - mean_absolute_error: 13896.3781 - val_loss: 20064.6610 - val_mean_absolute_error: 20064.6610
#
# Epoch 00441: val_loss did not improve from 19515.97544
# Epoch 442/500
# 1168/1168 [==============================] - 0s 141us/step - loss: 14340.3572 - mean_absolute_error: 14340.3572 - val_loss: 20186.2521 - val_mean_absolute_error: 20186.2521
#
# Epoch 00442: val_loss did not improve from 19515.97544
# Epoch 443/500
# 1168/1168 [==============================] - 0s 138us/step - loss: 14830.7936 - mean_absolute_error: 14830.7936 - val_loss: 20441.0262 - val_mean_absolute_error: 20441.0262
#
# Epoch 00443: val_loss did not improve from 19515.97544
# Epoch 444/500
# 1168/1168 [==============================] - 0s 132us/step - loss: 14580.4134 - mean_absolute_error: 14580.4134 - val_loss: 20267.2594 - val_mean_absolute_error: 20267.2594
#
# Epoch 00444: val_loss did not improve from 19515.97544
# Epoch 445/500
# 1168/1168 [==============================] - 0s 131us/step - loss: 14299.6303 - mean_absolute_error: 14299.6303 - val_loss: 20798.1647 - val_mean_absolute_error: 20798.1647
#
# Epoch 00445: val_loss did not improve from 19515.97544
# Epoch 446/500
# 1168/1168 [==============================] - 0s 140us/step - loss: 16933.0129 - mean_absolute_error: 16933.0129 - val_loss: 20423.0853 - val_mean_absolute_error: 20423.0853
#
# Epoch 00446: val_loss did not improve from 19515.97544
# Epoch 447/500
# 1168/1168 [==============================] - 0s 128us/step - loss: 14718.3396 - mean_absolute_error: 14718.3396 - val_loss: 20495.9944 - val_mean_absolute_error: 20495.9944
#
# Epoch 00447: val_loss did not improve from 19515.97544
# Epoch 448/500
# 1168/1168 [==============================] - 0s 124us/step - loss: 17073.8498 - mean_absolute_error: 17073.8498 - val_loss: 21637.5910 - val_mean_absolute_error: 21637.5910
#
# Epoch 00448: val_loss did not improve from 19515.97544
# Epoch 449/500
# 1168/1168 [==============================] - 0s 117us/step - loss: 14138.9752 - mean_absolute_error: 14138.9752 - val_loss: 20703.1521 - val_mean_absolute_error: 20703.1521
#
# Epoch 00449: val_loss did not improve from 19515.97544
# Epoch 450/500
# 1168/1168 [==============================] - 0s 119us/step - loss: 13975.6161 - mean_absolute_error: 13975.6161 - val_loss: 20138.0697 - val_mean_absolute_error: 20138.0697
#
# Epoch 00450: val_loss did not improve from 19515.97544
# Epoch 451/500
# 1168/1168 [==============================] - 0s 130us/step - loss: 14516.0392 - mean_absolute_error: 14516.0392 - val_loss: 19988.2850 - val_mean_absolute_error: 19988.2850
#
# Epoch 00451: val_loss did not improve from 19515.97544
# Epoch 452/500
# 1168/1168 [==============================] - 0s 127us/step - loss: 15680.2693 - mean_absolute_error: 15680.2693 - val_loss: 20048.6398 - val_mean_absolute_error: 20048.6398
#
# Epoch 00452: val_loss did not improve from 19515.97544
# Epoch 453/500
# 1168/1168 [==============================] - 0s 130us/step - loss: 15029.6469 - mean_absolute_error: 15029.6469 - val_loss: 23844.9312 - val_mean_absolute_error: 23844.9312
#
# Epoch 00453: val_loss did not improve from 19515.97544
# Epoch 454/500
# 1168/1168 [==============================] - 0s 128us/step - loss: 14421.2830 - mean_absolute_error: 14421.2830 - val_loss: 20543.0283 - val_mean_absolute_error: 20543.0283
#
# Epoch 00454: val_loss did not improve from 19515.97544
# Epoch 455/500
# 1168/1168 [==============================] - 0s 118us/step - loss: 15544.0377 - mean_absolute_error: 15544.0377 - val_loss: 21301.5869 - val_mean_absolute_error: 21301.5869
#
# Epoch 00455: val_loss did not improve from 19515.97544
# Epoch 456/500
# 1168/1168 [==============================] - 0s 119us/step - loss: 15844.6564 - mean_absolute_error: 15844.6564 - val_loss: 20798.3564 - val_mean_absolute_error: 20798.3564
#
# Epoch 00456: val_loss did not improve from 19515.97544
# Epoch 457/500
# 1168/1168 [==============================] - 0s 122us/step - loss: 14866.9571 - mean_absolute_error: 14866.9571 - val_loss: 20238.4282 - val_mean_absolute_error: 20238.4282
# Epoch 00457: val_loss did not improve from 19515.97544
# Epoch 458/500
# 1168/1168 [==============================] - 0s 113us/step - loss: 13790.2026 - mean_absolute_error: 13790.2026 - val_loss: 20820.3254 - val_mean_absolute_error: 20820.3254
#
# Epoch 00458: val_loss did not improve from 19515.97544
# Epoch 459/500
# 1168/1168 [==============================] - 0s 100us/step - loss: 14966.9425 - mean_absolute_error: 14966.9425 - val_loss: 19535.7304 - val_mean_absolute_error: 19535.7304
#
# Epoch 00459: val_loss did not improve from 19515.97544
# Epoch 460/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 14347.2413 - mean_absolute_error: 14347.2413 - val_loss: 20710.8878 - val_mean_absolute_error: 20710.8878
#
# Epoch 00460: val_loss did not improve from 19515.97544
# Epoch 461/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 15307.4004 - mean_absolute_error: 15307.4004 - val_loss: 20558.4513 - val_mean_absolute_error: 20558.4513
#
# Epoch 00461: val_loss did not improve from 19515.97544
# Epoch 462/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 13785.9237 - mean_absolute_error: 13785.9237 - val_loss: 21672.3376 - val_mean_absolute_error: 21672.3376
#
# Epoch 00462: val_loss did not improve from 19515.97544
# Epoch 463/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 13892.1409 - mean_absolute_error: 13892.1409 - val_loss: 19724.9972 - val_mean_absolute_error: 19724.9972
#
# Epoch 00463: val_loss did not improve from 19515.97544
# Epoch 464/500
# 1168/1168 [==============================] - 0s 109us/step - loss: 14689.5478 - mean_absolute_error: 14689.5478 - val_loss: 22746.1131 - val_mean_absolute_error: 22746.1131
#
# Epoch 00464: val_loss did not improve from 19515.97544
# Epoch 465/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14781.9384 - mean_absolute_error: 14781.9384 - val_loss: 21659.1847 - val_mean_absolute_error: 21659.1847
#
# Epoch 00465: val_loss did not improve from 19515.97544
# Epoch 466/500
# 1168/1168 [==============================] - 0s 111us/step - loss: 16010.5749 - mean_absolute_error: 16010.5749 - val_loss: 19420.9662 - val_mean_absolute_error: 19420.9662
#
# Epoch 00466: val_loss improved from 19515.97544 to 19420.96618, saving model to Weights-466--19420.96618.hdf5
# Epoch 467/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 13434.8327 - mean_absolute_error: 13434.8327 - val_loss: 19958.0080 - val_mean_absolute_error: 19958.0080
#
# Epoch 00467: val_loss did not improve from 19420.96618
# Epoch 468/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14326.2948 - mean_absolute_error: 14326.2948 - val_loss: 23258.1964 - val_mean_absolute_error: 23258.1964
#
# Epoch 00468: val_loss did not improve from 19420.96618
# Epoch 469/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 14479.6896 - mean_absolute_error: 14479.6896 - val_loss: 19831.6370 - val_mean_absolute_error: 19831.6370
#
# Epoch 00469: val_loss did not improve from 19420.96618
# Epoch 470/500
# 1168/1168 [==============================] - 0s 97us/step - loss: 15238.9568 - mean_absolute_error: 15238.9568 - val_loss: 20576.4292 - val_mean_absolute_error: 20576.4292
#
# Epoch 00470: val_loss did not improve from 19420.96618
# Epoch 471/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 14478.9098 - mean_absolute_error: 14478.9098 - val_loss: 20208.6784 - val_mean_absolute_error: 20208.6784
#
# Epoch 00471: val_loss did not improve from 19420.96618
# Epoch 472/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 15283.3052 - mean_absolute_error: 15283.3052 - val_loss: 23007.3250 - val_mean_absolute_error: 23007.3250
#
# Epoch 00472: val_loss did not improve from 19420.96618
# Epoch 473/500
# 1168/1168 [==============================] - 0s 98us/step - loss: 14958.8163 - mean_absolute_error: 14958.8163 - val_loss: 20261.6092 - val_mean_absolute_error: 20261.6092
#
# Epoch 00473: val_loss did not improve from 19420.96618
# Epoch 474/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14710.2063 - mean_absolute_error: 14710.2063 - val_loss: 20317.0852 - val_mean_absolute_error: 20317.0852
#
# Epoch 00474: val_loss did not improve from 19420.96618
# Epoch 475/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 16397.1657 - mean_absolute_error: 16397.1657 - val_loss: 21608.4041 - val_mean_absolute_error: 21608.4041
#
# Epoch 00475: val_loss did not improve from 19420.96618
# Epoch 476/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 15495.5607 - mean_absolute_error: 15495.5607 - val_loss: 20324.5142 - val_mean_absolute_error: 20324.5142
#
# Epoch 00476: val_loss did not improve from 19420.96618
# Epoch 477/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 14125.4782 - mean_absolute_error: 14125.4782 - val_loss: 20614.6784 - val_mean_absolute_error: 20614.6784
#
# Epoch 00477: val_loss did not improve from 19420.96618
# Epoch 478/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 14326.7559 - mean_absolute_error: 14326.7559 - val_loss: 19591.0712 - val_mean_absolute_error: 19591.0712
#
# Epoch 00478: val_loss did not improve from 19420.96618
# Epoch 479/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 15592.2678 - mean_absolute_error: 15592.2678 - val_loss: 20159.0393 - val_mean_absolute_error: 20159.0393
#
# Epoch 00479: val_loss did not improve from 19420.96618
# Epoch 480/500
# 1168/1168 [==============================] - 0s 102us/step - loss: 16614.4307 - mean_absolute_error: 16614.4307 - val_loss: 21407.6655 - val_mean_absolute_error: 21407.6655
#
# Epoch 00480: val_loss did not improve from 19420.96618
# Epoch 481/500
# 1168/1168 [==============================] - 0s 104us/step - loss: 14369.9970 - mean_absolute_error: 14369.9970 - val_loss: 20396.4986 - val_mean_absolute_error: 20396.4986
#
# Epoch 00481: val_loss did not improve from 19420.96618
# Epoch 482/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14841.3808 - mean_absolute_error: 14841.3808 - val_loss: 19824.9181 - val_mean_absolute_error: 19824.9181
#
# Epoch 00482: val_loss did not improve from 19420.96618
# Epoch 483/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 13773.3197 - mean_absolute_error: 13773.3197 - val_loss: 22182.5137 - val_mean_absolute_error: 22182.5137
#
# Epoch 00483: val_loss did not improve from 19420.96618
# Epoch 484/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 15570.3544 - mean_absolute_error: 15570.3544 - val_loss: 20179.4148 - val_mean_absolute_error: 20179.4148
#
# Epoch 00484: val_loss did not improve from 19420.96618
# Epoch 485/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14168.1642 - mean_absolute_error: 14168.1642 - val_loss: 20307.8465 - val_mean_absolute_error: 20307.8465
#
# Epoch 00485: val_loss did not improve from 19420.96618
# Epoch 486/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 14384.4273 - mean_absolute_error: 14384.4273 - val_loss: 23011.4749 - val_mean_absolute_error: 23011.4749
#
# Epoch 00486: val_loss did not improve from 19420.96618
# Epoch 487/500
# 1168/1168 [==============================] - 0s 101us/step - loss: 14724.9167 - mean_absolute_error: 14724.9167 - val_loss: 26921.1719 - val_mean_absolute_error: 26921.1719
#
# Epoch 00487: val_loss did not improve from 19420.96618
# Epoch 488/500
# 1168/1168 [==============================] - 0s 106us/step - loss: 15305.6849 - mean_absolute_error: 15305.6849 - val_loss: 21098.9474 - val_mean_absolute_error: 21098.9474
#
# Epoch 00488: val_loss did not improve from 19420.96618
# Epoch 489/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 13755.5775 - mean_absolute_error: 13755.5775 - val_loss: 19445.8840 - val_mean_absolute_error: 19445.8840
#
# Epoch 00489: val_loss did not improve from 19420.96618
# Epoch 490/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 15819.7901 - mean_absolute_error: 15819.7901 - val_loss: 25314.4435 - val_mean_absolute_error: 25314.4435
#
# Epoch 00490: val_loss did not improve from 19420.96618
# Epoch 491/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 15899.7683 - mean_absolute_error: 15899.7683 - val_loss: 19963.9403 - val_mean_absolute_error: 19963.9403
#
# Epoch 00491: val_loss did not improve from 19420.96618
# Epoch 492/500
# 1168/1168 [==============================] - 0s 128us/step - loss: 14429.2568 - mean_absolute_error: 14429.2568 - val_loss: 20311.0695 - val_mean_absolute_error: 20311.0695
#
# Epoch 00492: val_loss did not improve from 19420.96618
# Epoch 493/500
# 1168/1168 [==============================] - 0s 108us/step - loss: 16996.9130 - mean_absolute_error: 16996.9130 - val_loss: 19770.3664 - val_mean_absolute_error: 19770.3664
#
# Epoch 00493: val_loss did not improve from 19420.96618
# Epoch 494/500
# 1168/1168 [==============================] - 0s 119us/step - loss: 15566.3646 - mean_absolute_error: 15566.3646 - val_loss: 20085.1451 - val_mean_absolute_error: 20085.1451
#
# Epoch 00494: val_loss did not improve from 19420.96618
# Epoch 495/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 14758.9208 - mean_absolute_error: 14758.9208 - val_loss: 21413.9266 - val_mean_absolute_error: 21413.9266
#
# Epoch 00495: val_loss did not improve from 19420.96618
# Epoch 496/500
# 1168/1168 [==============================] - 0s 103us/step - loss: 14160.6164 - mean_absolute_error: 14160.6164 - val_loss: 19909.4548 - val_mean_absolute_error: 19909.4548
#
# Epoch 00496: val_loss did not improve from 19420.96618
# Epoch 497/500
# 1168/1168 [==============================] - 0s 99us/step - loss: 13649.8138 - mean_absolute_error: 13649.8138 - val_loss: 20091.0618 - val_mean_absolute_error: 20091.0618
#
# Epoch 00497: val_loss did not improve from 19420.96618
# Epoch 498/500
# 1168/1168 [==============================] - 0s 107us/step - loss: 13204.1295 - mean_absolute_error: 13204.1295 - val_loss: 20488.1163 - val_mean_absolute_error: 20488.1163
#
# Epoch 00498: val_loss did not improve from 19420.96618
# Epoch 499/500
# 1168/1168 [==============================] - 0s 105us/step - loss: 13624.5155 - mean_absolute_error: 13624.5155 - val_loss: 20033.4270 - val_mean_absolute_error: 20033.4270
#
# Epoch 00499: val_loss did not improve from 19420.96618
# Epoch 500/500
# 1168/1168 [==============================] - 0s 110us/step - loss: 14113.3819 - mean_absolute_error: 14113.3819 - val_loss: 22975.7185 - val_mean_absolute_error: 22975.7185
#
# Epoch 00500: val_loss did not improve from 19420.96618

# %%
# Load wights file of the best model :
wights_file = 'Weights-466--19420.96618.hdf5' # choose the best checkpoint 
NN_model.load_weights(wights_file) # load it
NN_model.compile(loss='mean_absolute_error', optimizer='adam', metrics=['mean_absolute_error'])

# %%
with h5py.File('Weights-466--19420.96618.hdf5', 'r') as hdf:
    ls = list(hdf.keys())
    print('list of dset in file:\n', ls)
    data = hdf.get('model_weight')
    
    print(data)
# Out:
# list of dset in file:
#  ['model_weights', 'optimizer_weights']
# None

# %% [markdown]
# We see that the validation loss of the best model is 18738.19

# %% [markdown]
# ## Fourth : Test the model
# We will submit the predictions on the test data to Kaggle and see how good our model is.

# %%
def make_submission(prediction, sub_name):
    my_submission = pd.DataFrame({'Id':pd.read_csv('test.csv').Id,'SalePrice':prediction})
    my_submission.to_csv('{}.csv'.format(sub_name),index=False)
    print('A submission file has been made')

# %%
predictions = NN_model.predict(test)

# %%
make_submission(predictions[:,0],'submission(NN).csv')
# Out:
# A submission file has been made

# %% [markdown]
# ## Fifth: Try another ML algorithms :
# Now, let us try another ML algorithm to compare the results.
#
# We will use random forest regressor and XGBRegressor.

# %% [markdown]
# **Split training data to training and validation data**

# %%
train_X, val_X, train_y, val_y = train_test_split(train, target, test_size = 0.25, random_state = 14)

# %% [markdown]
# **We will try Random forest model first.**

# %%
model = RandomForestRegressor()
model.fit(train_X,train_y)
# Out:
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=None,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=2,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=1,
#            oob_score=False, random_state=None, verbose=0, warm_start=False)

# %% [markdown]
# **Get the mean absolute error on the validation data **

# %%
predicted_prices = model.predict(val_X)
MAE = mean_absolute_error(val_y , predicted_prices)
print('Random forest validation MAE = ', MAE)
# Out:
# Random forest validation MAE =  19089.71589041096

# %% [markdown]
# **Make a submission file and submit it to Kaggle to see the result.**

# %%
predicted_prices = model.predict(test)
make_submission(predicted_prices,'Submission(RF).csv')

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/800/1*wcJqKzBsbLARqMjwvv0Xjw.png)

# %% [markdown]
# **Now, let us try XGBoost model**

# %%
XGBModel = XGBRegressor()
XGBModel.fit(train_X,train_y , verbose=False)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#        colsample_bytree=1, gamma=0, learning_rate=0.1, max_delta_step=0,
#        max_depth=3, min_child_weight=1, missing=None, n_estimators=100,
#        n_jobs=1, nthread=None, objective='reg:linear', random_state=0,
#        reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=None,
#        silent=True, subsample=1)

# %% [markdown]
# **Get the mean absolute error on the validation data**

# %%
XGBpredictions = XGBModel.predict(val_X)
MAE = mean_absolute_error(val_y , XGBpredictions)
print('XGBoost validation MAE = ',MAE)
# Out:
# XGBoost validation MAE =  17869.75410958904

# %% [markdown]
# **Make a submission file and submit it to Kaggle to see the result.**

# %%
XGBpredictions = XGBModel.predict(test)
make_submission(XGBpredictions,'Submission(XGB).csv')
# Out:
# A submission file has been made

# %% [markdown]
# ![](https://cdn-images-1.medium.com/max/800/1*PO0jxykz1hv-aSN5kkjItg.png)

# %% [markdown]
# Isn't that a surprise, I really did not think that neural networks will beat random forests and XGBoost algorithms, but let us try not to be too optimistic, remember that we did not configure any hyperparameters on random forest and XGBoost models, I believe if we did so, these two models would outscore neural networks.
