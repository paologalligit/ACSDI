# %%
import numpy as np
import pandas as pd
from re import sub
from time import time

from keras.models import Sequential
from keras.layers import Dense, BatchNormalization, Dropout
from keras_tqdm import TQDMNotebookCallback as ktqdm
from keras.utils import normalize
from keras.wrappers.scikit_learn import KerasRegressor
from keras.callbacks import TensorBoard
from keras.optimizers import Adam, SGD

from tensorflow.nn import relu, softmax

from sklearn import preprocessing
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import RobustScaler, MinMaxScaler, StandardScaler, Normalizer
from sklearn.impute import SimpleImputer
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error, r2_score

import scipy.stats as st

import seaborn as sns

import matplotlib.pyplot as plt
# Out:
# Using TensorFlow backend.

# %%
df = pd.read_csv('fifa19.csv')

# %%
df.drop(columns=['Unnamed: 0', 'ID', 'Photo', 'Flag', 'Club Logo', 'Real Face', 'Preferred Foot',
                 'Body Type', 'Jersey Number', 'Joined', 'Loaned From', 'Contract Valid Until'],inplace=True)

# %% [markdown]
# ## Obiettivo: predire valore dei giocatori

# %% [markdown]
# Pre-processing: convertire value, wage e release clause da string a float

# %%
curs=["Release Clause", "Value", "Wage"]

for cur in curs:
    def curr2val(x):
        x = str(x).replace('€', '')
        if 'K' in x: x = float(str(x).replace('K', '')) * 1000
        else: x = float(str(x).replace('M', '')) * 1000000
        return x
    df[cur] = df[cur].apply(curr2val)

# %% [markdown]
# Individuare eventuali outlier nella colonna value

# %%
def detect_outlier(data, threshold = 3):
    outliers=[]
    mean = np.mean(data)
    std = np.std(data)
    
    for y in data:
        score= (y - mean) / std 
        if np.abs(score) > threshold:
            outliers.append(y)
    return outliers

# %%
min_out = min(detect_outlier(df['Value'], threshold = 2))

df = df[df['Value'] < min_out] 
df = df[df['Value'] > 0]

# %% [markdown]
# Conversione in interi per le altre label

# %%
cols=["LS", "ST", "RS", "LW", "LF", "CF", "RF", "RW","LAM", "CAM", "RAM", "LM", "LCM", "CM", "RCM", "RM", "LWB", "LDM","CDM", "RDM", "RWB", "LB", "LCB", "CB", "RCB", "RB"]
for col in cols:
    df[col] = df[col].str[:-2]
    df[col] = df[col].astype(float)

# %%
df['Height'] = df['Height'].str.replace("'",'.')
df['Height'] = df['Height'].astype(float)

df['Weight'] = df['Weight'].str[:-3]
df['Weight'] = df['Weight'].astype(float)

# %% [markdown]
# Calcolo correlazione tra i valori per scegliere colonne significative

# %%
df_corr = df.corr()

fig = plt.figure(figsize=(50,20))
ax = fig.add_subplot(111)
cax = ax.matshow(df_corr,cmap='coolwarm', vmin=-1, vmax=1)
fig.colorbar(cax)

ticks = np.arange(0,len(df_corr.columns),1)
ax.set_xticks(ticks)
ax.set_xticklabels(df_corr.columns)
plt.xticks(rotation=90)
ax.set_yticks(ticks)
ax.set_yticklabels(df_corr.columns)

plt.show()

# %%
labels = []
for label in df_corr:
#     if df_corr['Value'][label] < 0 or df_corr['Value'][label] > 0.5: labels.append(label)
    if df_corr['Value'][label] > 0.6: labels.append(label)
        
df_flt = df[labels]        
df_flt.head()
# Out:
#      Overall  Potential       Value     Wage  Reactions  Release Clause
# 41        88         88   4000000.0  77000.0       79.0       7400000.0
# 102       85         85   9000000.0  38000.0       85.0      15300000.0
# 108       85         85   9000000.0  57000.0       83.0      17100000.0
# 152       84         84   4200000.0  95000.0       80.0       6900000.0
# 201       83         83  13000000.0  70000.0       78.0      24700000.0

# %% [markdown]
# Divido in training e testing set

# %%
train_perc = 0.85
train_slice = int(len(df_flt) * train_perc)

df_flt = df_flt.sample(frac=1)

train = df_flt.iloc[:train_slice, :]
test = df_flt.iloc[train_slice:, :]

len(train), len(test)
# Out:
# (14799, 2612)

# %%
y_train = train.loc[:, ['Value']]
X_train = train.drop(columns='Value')

y_test = test.loc[:, ['Value']]
X_test = test.drop(columns='Value')

# %% [markdown]
# Sostiuisco eventuali valori nan con la media della colonna

# %%
imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer = imputer.fit(X_train)
X_train = imputer.transform(X_train)

imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer = imputer.fit(y_train)
y_train = imputer.transform(y_train)

imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer = imputer.fit(X_test)
X_test = imputer.transform(X_test)

imputer = SimpleImputer(missing_values = np.nan, strategy = 'mean')
imputer = imputer.fit(y_test)
y_test = imputer.transform(y_test)

# %% [markdown]
# Scalo i valori, sia per i caratteri che per il target

# %%
# scaler = RobustScaler()
# scaler = scaler.fit(X_train)
# X_train = scaler.transform(X_train)

# X_train_scaled = preprocessing.scale(X_train)
scaler = StandardScaler().fit(X_train)
X_train_scaled = scaler.transform(X_train)

scaler_train = StandardScaler().fit(y_train)
y_train_scaled = scaler_train.transform(y_train) 
# X_train_scaled, X_test_scaled


scaler = StandardScaler().fit(X_test)
X_test_scaled = scaler.transform(X_test)

scaler_test = StandardScaler().fit(y_test)
y_test_scaled = scaler_test.transform(y_test)

# %% [markdown]
# Estraggo i sottoinsiemi per training e validation

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train_scaled, y_train_scaled, test_size = 0.15, random_state = 42)

# %%
def coeff_determination(y_test, y_pred):
    from keras import backend as K
    SS_res =  K.sum(K.square( y_test-y_pred ))
    SS_tot = K.sum(K.square( y_test - K.mean(y_test) ) )
    return ( 1 - SS_res/(SS_tot + K.epsilon()))

# %%
def build_nn(neurons):
    model = Sequential()
    # Adding the input layer and the first hidden layer
    model.add(Dense(300, activation = 'relu', input_dim = neurons))
#     model.add(Dropout(0.01))
    
    # Adding the second hidden layer
    model.add(Dense(256, activation = 'relu'))
#     model.add(Dropout(0.01))
    
    # Adding the third hidden layer
    model.add(Dense(128, activation = 'relu'))

    # Adding the output layer
    model.add(Dense(1, activation = 'linear'))
    
    return model

# %%
nn = build_nn(X_train.shape[1])
# Out:
# WARNING:tensorflow:From /home/paologio/.local/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
nn.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 300)               1800
# _________________________________________________________________
# dense_2 (Dense)              (None, 256)               77056
# _________________________________________________________________
# dense_3 (Dense)              (None, 128)               32896
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 111,881
# Trainable params: 111,881
# Non-trainable params: 0
# _________________________________________________________________

# %%
ts_board = TensorBoard(log_dir='value_predictions/{}'.format(time()))

# %%
opt = Adam(lr=0.001, beta_1=0.75, beta_2=0.999, epsilon=0.001, decay=0.0, amsgrad=False)
# opt = SGD(lr=0.01, momentum=0.9)

nn.compile(optimizer = opt, loss = 'mean_absolute_error', metrics = [coeff_determination])

history = nn.fit(X_train, y_train, batch_size=256, epochs=50, callbacks=[ts_board], validation_data=(X_val, y_val), shuffle=True)
# Out:
# WARNING:tensorflow:From /home/paologio/.local/lib/python3.6/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 12579 samples, validate on 2220 samples
# Epoch 1/50
# 12579/12579 [==============================] - 0s 34us/step - loss: 0.2326 - coeff_determination: 0.7726 - val_loss: 0.0970 - val_coeff_determination: 0.9403
# Epoch 2/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0965 - coeff_determination: 0.9327 - val_loss: 0.0979 - val_coeff_determination: 0.9452
# Epoch 3/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0954 - coeff_determination: 0.9344 - val_loss: 0.0955 - val_coeff_determination: 0.9474
# Epoch 4/50
# 12579/12579 [==============================] - 0s 24us/step - loss: 0.0923 - coeff_determination: 0.9404 - val_loss: 0.0847 - val_coeff_determination: 0.9499
# Epoch 5/50
# 12579/12579 [==============================] - 0s 24us/step - loss: 0.0902 - coeff_determination: 0.9414 - val_loss: 0.0946 - val_coeff_determination: 0.9514
# Epoch 6/50
# 12579/12579 [==============================] - 0s 24us/step - loss: 0.0901 - coeff_determination: 0.9456 - val_loss: 0.0897 - val_coeff_determination: 0.9444
# Epoch 7/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0874 - coeff_determination: 0.9458 - val_loss: 0.1017 - val_coeff_determination: 0.9453
# Epoch 8/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0856 - coeff_determination: 0.9499 - val_loss: 0.0835 - val_coeff_determination: 0.9585
# Epoch 9/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0828 - coeff_determination: 0.9534 - val_loss: 0.0823 - val_coeff_determination: 0.9541
# Epoch 10/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0802 - coeff_determination: 0.9549 - val_loss: 0.0817 - val_coeff_determination: 0.9617
# Epoch 11/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0806 - coeff_determination: 0.9579 - val_loss: 0.0761 - val_coeff_determination: 0.9654
# Epoch 12/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0781 - coeff_determination: 0.9605 - val_loss: 0.0723 - val_coeff_determination: 0.9662
# Epoch 13/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0750 - coeff_determination: 0.9634 - val_loss: 0.0730 - val_coeff_determination: 0.9695
# Epoch 14/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0736 - coeff_determination: 0.9667 - val_loss: 0.0761 - val_coeff_determination: 0.9654
# Epoch 15/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0727 - coeff_determination: 0.9661 - val_loss: 0.0780 - val_coeff_determination: 0.9684
# Epoch 16/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0738 - coeff_determination: 0.9675 - val_loss: 0.0723 - val_coeff_determination: 0.9717
# Epoch 17/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0708 - coeff_determination: 0.9687 - val_loss: 0.0943 - val_coeff_determination: 0.9571
# Epoch 18/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0695 - coeff_determination: 0.9687 - val_loss: 0.0708 - val_coeff_determination: 0.9742
# Epoch 19/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0667 - coeff_determination: 0.9709 - val_loss: 0.0772 - val_coeff_determination: 0.9682
# Epoch 20/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0678 - coeff_determination: 0.9709 - val_loss: 0.0703 - val_coeff_determination: 0.9724
# Epoch 21/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0661 - coeff_determination: 0.9711 - val_loss: 0.0732 - val_coeff_determination: 0.9745
# Epoch 22/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0671 - coeff_determination: 0.9719 - val_loss: 0.0761 - val_coeff_determination: 0.9714
# Epoch 23/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0660 - coeff_determination: 0.9707 - val_loss: 0.0752 - val_coeff_determination: 0.9658
# Epoch 24/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0653 - coeff_determination: 0.9717 - val_loss: 0.0688 - val_coeff_determination: 0.9734
# Epoch 25/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0652 - coeff_determination: 0.9717 - val_loss: 0.0663 - val_coeff_determination: 0.9715
# Epoch 26/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0637 - coeff_determination: 0.9724 - val_loss: 0.0657 - val_coeff_determination: 0.9734
# Epoch 27/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0639 - coeff_determination: 0.9719 - val_loss: 0.0627 - val_coeff_determination: 0.9744
# Epoch 28/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0639 - coeff_determination: 0.9732 - val_loss: 0.0673 - val_coeff_determination: 0.9731
# Epoch 29/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0638 - coeff_determination: 0.9733 - val_loss: 0.0623 - val_coeff_determination: 0.9763
# Epoch 30/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0631 - coeff_determination: 0.9736 - val_loss: 0.0668 - val_coeff_determination: 0.9725
# Epoch 31/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0630 - coeff_determination: 0.9733 - val_loss: 0.0634 - val_coeff_determination: 0.9723
# Epoch 32/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0622 - coeff_determination: 0.9751 - val_loss: 0.0727 - val_coeff_determination: 0.9715
# Epoch 33/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0629 - coeff_determination: 0.9742 - val_loss: 0.0664 - val_coeff_determination: 0.9753
# Epoch 34/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0631 - coeff_determination: 0.9748 - val_loss: 0.0694 - val_coeff_determination: 0.9762
# Epoch 35/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0622 - coeff_determination: 0.9756 - val_loss: 0.0656 - val_coeff_determination: 0.9743
# Epoch 36/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0624 - coeff_determination: 0.9742 - val_loss: 0.0614 - val_coeff_determination: 0.9762
# Epoch 37/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0611 - coeff_determination: 0.9742 - val_loss: 0.0621 - val_coeff_determination: 0.9757
# Epoch 38/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0630 - coeff_determination: 0.9740 - val_loss: 0.0618 - val_coeff_determination: 0.9769
# Epoch 39/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0607 - coeff_determination: 0.9752 - val_loss: 0.0624 - val_coeff_determination: 0.9755
# Epoch 40/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0609 - coeff_determination: 0.9756 - val_loss: 0.0626 - val_coeff_determination: 0.9744
# Epoch 41/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0619 - coeff_determination: 0.9741 - val_loss: 0.0605 - val_coeff_determination: 0.9771
# Epoch 42/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0602 - coeff_determination: 0.9766 - val_loss: 0.0637 - val_coeff_determination: 0.9748
# Epoch 43/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0616 - coeff_determination: 0.9753 - val_loss: 0.0627 - val_coeff_determination: 0.9765
# Epoch 44/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0603 - coeff_determination: 0.9759 - val_loss: 0.0625 - val_coeff_determination: 0.9759
# Epoch 45/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0600 - coeff_determination: 0.9765 - val_loss: 0.0664 - val_coeff_determination: 0.9732
# Epoch 46/50
# 12579/12579 [==============================] - 0s 23us/step - loss: 0.0606 - coeff_determination: 0.9766 - val_loss: 0.0609 - val_coeff_determination: 0.9782
# Epoch 47/50
# 12579/12579 [==============================] - 0s 22us/step - loss: 0.0597 - coeff_determination: 0.9765 - val_loss: 0.0625 - val_coeff_determination: 0.9778
# Epoch 48/50
# 12579/12579 [==============================] - 0s 21us/step - loss: 0.0588 - coeff_determination: 0.9779 - val_loss: 0.0655 - val_coeff_determination: 0.9741
# Epoch 49/50
# 12579/12579 [==============================] - 0s 21us/step - loss: 0.0594 - coeff_determination: 0.9779 - val_loss: 0.0614 - val_coeff_determination: 0.9766
# Epoch 50/50
# 12579/12579 [==============================] - 0s 21us/step - loss: 0.0588 - coeff_determination: 0.9778 - val_loss: 0.0803 - val_coeff_determination: 0.9682

# %%
def mean_abs_error(prediction, target):
    res = 0
    tot = 0
    for i in range(len(target)):
        if target[i][0] != 0 and not np.isnan(prediction[i][0]):
#             print(prediction[i][0], target[i][0])
            res += abs(prediction[i][0] - target[i][0])
            tot += 1
    print(tot, len(target), len(prediction))
    return round(res / tot, 2)

# %%
res = nn.predict(X_test_scaled)
res = scaler_train.inverse_transform(res)
mean_abs_error(res, y_test), max(y_test), round(r2_score(y_test, res), 4)
# Out:
# 2612 2612 2612
# (197790.36, array([13500000.]), 0.9717)

# %%
loss, acc = nn.evaluate(X_test_scaled, y_test_scaled, verbose=1)
print('Test loss:', loss)
print('Test accuracy:', acc)
# Out:
# 2612/2612 [==============================] - 0s 28us/step
# Test loss: 0.0804975880552397
# Test accuracy: 0.965491222842364

# %%
import matplotlib.pyplot as plt

_, ax = plt.subplots(1, 1, figsize=(10, 10))
ax.scatter(x = range(0, y_test.size), y=y_test, c = 'green', label = 'Actual', alpha = 0.4)
ax.scatter(x = range(0, res.size), y=res, c = 'red', label = 'Predicted', alpha = 0.4)
plt.title('Actual vs. Predicted')
plt.xlabel('Test Size')
plt.ylabel('Value')
def millions(x, pos):
    return '€%1.1fM' % (x * 1e-6)
ax.yaxis.set_major_formatter(plt.FuncFormatter(millions))
plt.legend()
plt.show()
