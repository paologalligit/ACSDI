 99.07}, {'R2': 98.94}, {'R2': 98.8}, {'R2': 98.93}, {'R2': 99.1}]}, {'n_[30]': [{'R2': 99.15}, {'R2': 99.13}, {'R2': 98.8}, {'R2': 98.96}, {'R2': 99.06}]}, {'n_[40]': [{'R2': 99.09}, {'R2': 99.07}, {'R2': 98.94}, {'R2': 98.91}, {'R2': 99.04}]}, {'n_[50]': [{'R2': 99.09}, {'R2': 99.07}, {'R2': 98.83}, {'R2': 99.0}, {'R2': 99.05}]}, {'n_[60]': [{'R2': 99.04}, {'R2': 99.15}, {'R2': 98.93}, {'R2': 98.99}, {'R2': 99.05}]}, {'n_[70]': [{'R2': 99.09}, {'R2': 99.17}, {'R2': 98.9}, {'R2': 99.09}, {'R2': 99.15}]}, {'n_[80]': [{'R2': 99.2}, {'R2': 99.11}, {'R2': 98.97}, {'R2': 99.07}, {'R2': 99.11}]}, {'n_[90]': [{'R2': 99.21}, {'R2': 99.14}, {'R2': 98.88}, {'R2': 99.11}, {'R2': 99.07}]}, {'n_[100]': [{'R2': 99.19}, {'R2': 99.22}, {'R2': 98.9}, {'R2': 99.01}, {'R2': 99.12}]}, {'n_[110]': [{'R2': 99.2}, {'R2': 99.18}, {'R2': 98.9}, {'R2': 99.07}, {'R2': 99.1}]}, {'n_[120]': [{'R2': 99.18}, {'R2': 99.17}, {'R2': 98.99}, {'R2': 99.11}, {'R2': 99.12}]}]}]

# %%
d
# Out:
# [{'fold_0': [{'n_[20]': [{'R2': 98.98},
#      {'R2': 98.88},
#      {'R2': 99.2},
#      {'R2': 98.88},
#      {'R2': 99.16}]},
#    {'n_[30]': [{'R2': 98.93},
#      {'R2': 98.99},
#      {'R2': 99.15},
#      {'R2': 98.79},
#      {'R2': 99.24}]},
#    {'n_[40]': [{'R2': 99.01},
#      {'R2': 99.11},
#      {'R2': 99.19},
#      {'R2': 98.9},
#      {'R2': 99.2}]},
#    {'n_[50]': [{'R2': 99.01},
#      {'R2': 99.02},
#      {'R2': 99.2},
#      {'R2': 98.89},
#      {'R2': 99.2}]},
#    {'n_[60]': [{'R2': 99.09},
#      {'R2': 99.08},
#      {'R2': 99.08},
#      {'R2': 98.94},
#      {'R2': 99.22}]},
#    {'n_[70]': [{'R2': 98.94},
#      {'R2': 99.05},
#      {'R2': 99.1},
#      {'R2': 98.97},
#      {'R2': 99.18}]},
#    {'n_[80]': [{'R2': 99.02},
#      {'R2': 99.06},
#      {'R2': 99.08},
#      {'R2': 98.83},
#      {'R2': 99.14}]},
#    {'n_[90]': [{'R2': 99.06},
#      {'R2': 99.08},
#      {'R2': 99.16},
#      {'R2': 98.84},
#      {'R2': 99.1}]},
# ...

# %%
c = 0

for fold in d:
    print('FOLD {}'.format(c))
    c += 1
    for key, value in fold.items():
#         print(value, '\n\n\n\n')
        for neurons in value:
            print(neurons.keys())
            for k, v in neurons.items():
                res = 0
                for r2 in v:
                    res += r2['R2']
                print(res / len(v))
    print('\n\n')
# Out:
# FOLD 0
# dict_keys(['n_[20]'])
# 99.02000000000001
# dict_keys(['n_[30]'])
# 99.02000000000001
# dict_keys(['n_[40]'])
# 99.08200000000001
# dict_keys(['n_[50]'])
# 99.064
# dict_keys(['n_[60]'])
# 99.082
# dict_keys(['n_[70]'])
# 99.04800000000002
# dict_keys(['n_[80]'])
# 99.02599999999998
# dict_keys(['n_[90]'])
# 99.048
# dict_keys(['n_[100]'])
# 99.07000000000001
# dict_keys(['n_[110]'])
# 99.072
# dict_keys(['n_[120]'])
# 99.066
#
#
#
# FOLD 1
# dict_keys(['n_[20]'])
# 99.06200000000001
# dict_keys(['n_[30]'])
# 99.042
# dict_keys(['n_[40]'])
# 99.102
# dict_keys(['n_[50]'])
# 99.128
# dict_keys(['n_[60]'])
# 99.15199999999999
# dict_keys(['n_[70]'])
# 99.136
# dict_keys(['n_[80]'])
# 99.11800000000001
# dict_keys(['n_[90]'])
# 99.13399999999999
# dict_keys(['n_[100]'])
# 99.138
# dict_keys(['n_[110]'])
# 99.11800000000001
# dict_keys(['n_[120]'])
# 99.11600000000001
#
#
#
# FOLD 2
# dict_keys(['n_[20]'])
# 98.968
# dict_keys(['n_[30]'])
# 99.02
# dict_keys(['n_[40]'])
# 99.01
# ...

# %%
d = [{'fold_0': [{'n_[130]': [{'R2': 98.98}, {'R2': 99.09}, {'R2': 99.09}, {'R2': 98.83}, {'R2': 99.24}]}, {'n_[140]': [{'R2': 99.06}, {'R2': 99.01}, {'R2': 99.17}, {'R2': 98.94}, {'R2': 99.21}]}, {'n_[150]': [{'R2': 98.98}, {'R2': 99.03}, {'R2': 99.18}, {'R2': 98.97}, {'R2': 99.25}]}, {'n_[160]': [{'R2': 99.05}, {'R2': 99.04}, {'R2': 99.13}, {'R2': 98.9}, {'R2': 99.23}]}, {'n_[170]': [{'R2': 99.0}, {'R2': 99.06}, {'R2': 99.2}, {'R2': 98.95}, {'R2': 99.21}]}, {'n_[180]': [{'R2': 99.06}, {'R2': 99.05}, {'R2': 99.15}, {'R2': 98.94}, {'R2': 99.27}]}, {'n_[190]': [{'R2': 99.08}, {'R2': 99.08}, {'R2': 99.15}, {'R2': 98.96}, {'R2': 99.2}]}, {'n_[200]': [{'R2': 99.04}, {'R2': 99.11}, {'R2': 99.22}, {'R2': 98.9}, {'R2': 99.23}]}]}, {'fold_1': [{'n_[130]': [{'R2': 99.1}, {'R2': 99.12}, {'R2': 99.1}, {'R2': 99.12}, {'R2': 99.18}]}, {'n_[140]': [{'R2': 99.12}, {'R2': 99.22}, {'R2': 99.06}, {'R2': 99.02}, {'R2': 99.18}]}, {'n_[150]': [{'R2': 99.13}, {'R2': 99.19}, {'R2': 99.12}, {'R2': 99.12}, {'R2': 99.19}]}, {'n_[160]': [{'R2': 99.18}, {'R2': 99.19}, {'R2': 99.0}, {'R2': 98.95}, {'R2': 99.25}]}, {'n_[170]': [{'R2': 99.14}, {'R2': 99.19}, {'R2': 99.03}, {'R2': 98.98}, {'R2': 99.18}]}, {'n_[180]': [{'R2': 99.11}, {'R2': 99.16}, {'R2': 99.07}, {'R2': 99.17}, {'R2': 99.2}]}, {'n_[190]': [{'R2': 99.1}, {'R2': 99.18}, {'R2': 98.96}, {'R2': 99.05}, {'R2': 99.23}]}, {'n_[200]': [{'R2': 99.14}, {'R2': 99.14}, {'R2': 99.02}, {'R2': 99.14}, {'R2': 99.14}]}]}, {'fold_2': [{'n_[130]': [{'R2': 99.16}, {'R2': 99.13}, {'R2': 98.95}, {'R2': 99.03}, {'R2': 99.17}]}, {'n_[140]': [{'R2': 99.14}, {'R2': 99.23}, {'R2': 98.95}, {'R2': 98.95}, {'R2': 99.12}]}, {'n_[150]': [{'R2': 99.17}, {'R2': 99.21}, {'R2': 98.91}, {'R2': 99.06}, {'R2': 99.1}]}, {'n_[160]': [{'R2': 99.16}, {'R2': 99.14}, {'R2': 98.91}, {'R2': 99.04}, {'R2': 99.07}]}, {'n_[170]': [{'R2': 99.18}, {'R2': 99.19}, {'R2': 98.9}, {'R2': 98.97}, {'R2': 99.11}]}, {'n_[180]': [{'R2': 99.19}, {'R2': 99.16}, {'R2': 98.87}, {'R2': 99.05}, {'R2': 99.12}]}, {'n_[190]': [{'R2': 99.16}, {'R2': 99.19}, {'R2': 98.91}, {'R2': 99.07}, {'R2': 99.11}]}, {'n_[200]': [{'R2': 99.16}, {'R2': 99.18}, {'R2': 98.91}, {'R2': 99.03}, {'R2': 99.12}]}]}]

# %%
c = 0

for fold in d:
    print('FOLD {}'.format(c))
    c += 1
    for key, value in fold.items():
#         print(value, '\n\n\n\n')
        for neurons in value:
            print(neurons.keys())
            for k, v in neurons.items():
                res = 0
                for r2 in v:
                    res += r2['R2']
                print(res / len(v))
    print('\n\n')
# Out:
# FOLD 0
# dict_keys(['n_[130]'])
# 99.04599999999999
# dict_keys(['n_[140]'])
# 99.078
# dict_keys(['n_[150]'])
# 99.082
# dict_keys(['n_[160]'])
# 99.07000000000001
# dict_keys(['n_[170]'])
# 99.08399999999999
# dict_keys(['n_[180]'])
# 99.094
# dict_keys(['n_[190]'])
# 99.094
# dict_keys(['n_[200]'])
# 99.1
#
#
#
# FOLD 1
# dict_keys(['n_[130]'])
# 99.124
# dict_keys(['n_[140]'])
# 99.11999999999999
# dict_keys(['n_[150]'])
# 99.15
# dict_keys(['n_[160]'])
# 99.114
# dict_keys(['n_[170]'])
# 99.10400000000001
# dict_keys(['n_[180]'])
# 99.142
# dict_keys(['n_[190]'])
# 99.10400000000001
# dict_keys(['n_[200]'])
# 99.116
#
#
#
# FOLD 2
# dict_keys(['n_[130]'])
# 99.088
# dict_keys(['n_[140]'])
# 99.078
# dict_keys(['n_[150]'])
# 99.08999999999999
# dict_keys(['n_[160]'])
# 99.06400000000001
# dict_keys(['n_[170]'])
# 99.07000000000001
# dict_keys(['n_[180]'])
# 99.078
# dict_keys(['n_[190]'])
# 99.088
# dict_keys(['n_[200]'])
# 99.08
